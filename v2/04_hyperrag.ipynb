# %% [markdown]
# # HyperRAG V2 — Notebook 4: HyperRAG + Final Comparison
#
# **Goal:** Build HyperRAG, understand how the hyperlink graph improves multi-hop retrieval, and produce a final 3-system comparison chart.
#
# **HyperRAG adds one extra step on top of Simple RAG:**
#
# ```
# Simple RAG:  query → FAISS → top-k pages
# HyperRAG  :  query → FAISS → top-k pages → 1-hop graph expansion → re-rank → top-k + expand_k pages
# ```
#
# **Why does this help for multi-hop questions?**
# A question like *"What is the birthplace of the director of Inception?"* needs:
# 1. Page about *Inception* (to find director = Christopher Nolan)
# 2. Page about *Christopher Nolan* (to find birthplace = London)
#
# FAISS might find the Inception page but miss Nolan's page. The hyperlink graph then expands to Nolan's page because Inception's article links to it.
#
# **Prerequisite:** Run notebooks 01, 02, and 03 first.

# %%
import json
import html as html_lib
from pathlib import Path
from collections import Counter

import faiss
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from bs4 import BeautifulSoup
from sentence_transformers import SentenceTransformer

# ── Paths ─────────────────────────────────────────────────────────────────────
if Path('utils.py').exists():
    BASE_DIR = Path('.')
elif Path('v2/utils.py').exists():
    BASE_DIR = Path('v2')
else:
    raise FileNotFoundError('Run from v2/ or from HyperRAG-M2/')

DATA_DIR = BASE_DIR / 'data'

with open(DATA_DIR / 'corpus_001.json')    as f: corpus    = json.load(f)
with open(DATA_DIR / 'questions_001.json') as f: questions = json.load(f)

print(f'Corpus    : {len(corpus)} pages')
print(f'Questions : {len(questions)} questions')
# Out:
# W0427 23:19:44.611000 94160 site-packages\torch\distributed\elastic\multiprocessing\redirects.py:29] NOTE: Redirects are currently not supported in Windows or MacOs.
# Corpus    : 9999 pages
# Questions : 5329 questions

# %% [markdown]
# ---
# ## Step 1 — Extract Hyperlinks from Wikipedia HTML
#
# Each Wikipedia page contains links to other Wikipedia articles. We extract these from the HTML `<a href>` tags. These links form the edges of the hyperlink graph.

# %%
def extract_links(html: str) -> list[str]:
    """
    Extract Wikipedia article titles from HTML <a href> links.
    Only keeps links that start with /wiki/ and have no colon in the title
    (colons indicate non-article pages like Category:, File:, Talk:, etc.).
    Returns deduplicated list of article titles.
    """
    soup  = BeautifulSoup(html, 'html.parser')
    seen  = set()
    titles = []
    for a in soup.find_all('a', href=True):
        href = a['href']
        if href.startswith('/wiki/') and ':' not in href[6:]:
            title = href[6:].replace('_', ' ')
            title = html_lib.unescape(title)
            if title and title not in seen:
                seen.add(title)
                titles.append(title)
    return titles


print('extract_links() defined.')
# Out:
# extract_links() defined.

# %%
# ── Test: extract links from the first corpus page ────────────────────────────
page  = corpus[0]
links = extract_links(page['html'])

print(f'Page  : {page["title"]}')
print(f'Links found in HTML: {len(links)}')
print()
print('First 15 links:')
for i, l in enumerate(links[:15], 1):
    print(f'  {i:2d}. {l}')
print()
print('Note: These are OTHER Wikipedia articles this page links to.')
# Out:
# Page  : The Oberoi Group
# Links found in HTML: 377
#
# First 15 links:
#    1. Private company
#    2. Hospitality industry
#    3. Mohan Singh Oberoi
#    4. New Delhi
#    5. India
#    6. Hotel
#    7. Resort
#    8. Luxury hotel
#    9. River cruise
#   10. Asia
#   11. Rai Bahadur
#   12. Delhi
#   13. Shimla
#   14. Prithvi Raj Singh Oberoi
#   15. Trident Hotel, Nariman Point
#
# Note: These are OTHER Wikipedia articles this page links to.

# %%
# Compare links from HTML extraction vs links stored in corpus["links"]
# (corpus["links"] was fetched via the Wikipedia API in notebook 01)
api_links  = set(page['links'])
html_links = set(links)

print(f'Links from Wikipedia API  : {len(api_links)}')
print(f'Links extracted from HTML : {len(html_links)}')
print(f'Overlap                   : {len(api_links & html_links)}')
print(f'Only in API               : {len(api_links - html_links)}')
print(f'Only in HTML              : {len(html_links - api_links)}')
print()
print('We will use corpus["links"] (API links) for the graph — they are cleaner.')
# Out:
# Links from Wikipedia API  : 372
# Links extracted from HTML : 377
# Overlap                   : 320
# Only in API               : 52
# Only in HTML              : 57
#
# We will use corpus["links"] (API links) for the graph — they are cleaner.

# %% [markdown]
# ---
# ## Step 2 — Build the Hyperlink Graph
#
# We build a **directed graph** where:
# - Each node is a Wikipedia page title
# - Each directed edge (A → B) means page A contains a link to page B
#
# We only keep nodes that are in our corpus — this keeps the graph small and focused.

# %%
def build_graph(corpus: list[dict]) -> nx.DiGraph:
    """
    Build a directed hyperlink graph from corpus pages.
    Nodes = page titles that are in the corpus.
    Edges = hyperlinks between corpus pages.
    Only edges where both source AND target are in the corpus are added.
    """
    corpus_titles = {p['title'] for p in corpus}
    G = nx.DiGraph()
    G.add_nodes_from(corpus_titles)   # add all corpus pages as nodes

    edge_count = 0
    for page in corpus:
        src = page['title']
        for link in page['links']:
            if link in corpus_titles and link != src:
                G.add_edge(src, link)
                edge_count += 1

    return G


print('build_graph() defined.')
# Out:
# build_graph() defined.

# %%
graph = build_graph(corpus)

print('Graph Statistics')
print('=' * 40)
print(f'Nodes (pages)    : {graph.number_of_nodes()}')
print(f'Edges (hyperlinks): {graph.number_of_edges()}')
print(f'Density           : {nx.density(graph):.4f}')
print()
print('Out-degree (how many corpus pages this page links to):')
for node, deg in sorted(graph.out_degree(), key=lambda x: -x[1]):
    print(f'  {node[:45]:<45} → {deg} links')
print()
print('In-degree (how many corpus pages link TO this page):')
for node, deg in sorted(graph.in_degree(), key=lambda x: -x[1]):
    print(f'  {node[:45]:<45} ← {deg} links')
# Out:
# Graph Statistics
# ========================================
# Nodes (pages)    : 9999
# Edges (hyperlinks): 86244
# Density           : 0.0009
#
# Out-degree (how many corpus pages this page links to):
#   Barbra Streisand                              → 171 links
#   Cher                                          → 141 links
#   Taylor Swift                                  → 135 links
#   Elton John                                    → 133 links
#   Dustin Hoffman                                → 133 links
#   Steven Spielberg                              → 129 links
#   Judi Dench                                    → 127 links
#   Frank Sinatra                                 → 126 links
#   Clint Eastwood                                → 123 links
#   Mel Brooks                                    → 121 links
#   Julie Andrews                                 → 120 links
#   Paul Newman                                   → 119 links
#   Bill Murray                                   → 111 links
#   Jack Nicholson                                → 110 links
#   Eminem                                        → 109 links
#   Culture of the United Kingdom                 → 107 links
#   Oprah Winfrey                                 → 107 links
#   Ben Kingsley                                  → 106 links
#   John Lithgow                                  → 104 links
#   Woody Allen                                   → 101 links
#   Samuel L. Jackson                             → 100 links
#   Madonna (entertainer)                         → 98 links
#   Alec Guinness                                 → 98 links
#   Kevin Spacey                                  → 98 links
#   Scarlett Johansson                            → 97 links
#   Brad Pitt                                     → 96 links
#   Stephen Sondheim                              → 96 links
#   Dwight D. Eisenhower                          → 96 links
#   Ronald Reagan                                 → 93 links
#   Michael Douglas                               → 93 links
#   Willie Nelson                                 → 92 links
#   George Harrison                               → 91 links
#   Barack Obama                                  → 91 links
#   Johnny Depp                                   → 89 links
#   Gregory Peck                                  → 88 links
#   Miley Cyrus                                   → 88 links
#   Diane Keaton                                  → 86 links
#   Albert Finney                                 → 86 links
#   Bradley Cooper                                → 85 links
#   Mark Rylance                                  → 83 links
#   Jason Robards                                 → 83 links
#   Martin Luther King Jr.                        → 83 links
#   James Franco                                  → 82 links
#   Jimmy Carter                                  → 81 links
#   Olivia Colman                                 → 80 links
#   Sophia Loren                                  → 80 links
#   Benedict Cumberbatch                          → 79 links
#   Mark Ruffalo                                  → 78 links
#   Christopher Nolan                             → 77 links
#   Sally Field                                   → 77 links
#   Spice Girls                                   → 77 links
#   Mark Ronson                                   → 77 links
#   Elvis Presley                                 → 76 links
#   Quentin Tarantino                             → 76 links
#   Neil Diamond                                  → 75 links
#   Charlton Heston                               → 74 links
#   Philip Seymour Hoffman                        → 74 links
#   Lyndon B. Johnson                             → 73 links
#   Hugh Grant                                    → 73 links
#   Liza Minnelli                                 → 73 links
#   Tim Burton                                    → 73 links
#   Lily Tomlin                                   → 72 links
#   Bob Hope                                      → 72 links
#   Lupita Nyong'o                                → 71 links
#   Tammy Wynette                                 → 70 links
#   Stephen Colbert                               → 70 links
#   Richard Nixon                                 → 70 links
#   Katharine Hepburn                             → 70 links
#   Charlie Chaplin                               → 69 links
#   Heath Ledger                                  → 69 links
#   Henry Clay                                    → 69 links
#   Shaquille O'Neal                              → 68 links
#   Billy Wilder                                  → 68 links
#   Theodore Roosevelt                            → 68 links
#   Richard Pryor                                 → 68 links
#   Stanley Tucci                                 → 67 links
#   Bee Gees                                      → 67 links
#   Annette Bening                                → 67 links
#   Bob Dole                                      → 67 links
#   Penélope Cruz                                 → 67 links
#   Marilyn Horne                                 → 67 links
#   Marvin Hamlisch                               → 66 links
#   Tom Brady                                     → 66 links
#   The Lion King                                 → 66 links
#   Alan Arkin                                    → 65 links
#   Hayao Miyazaki                                → 65 links
#   Democracy in America                          → 65 links
#   Harry Styles                                  → 64 links
#   Casey Affleck                                 → 64 links
#   Demi Moore                                    → 64 links
#   Dennis Rodman                                 → 63 links
#   Liberal conservatism                          → 63 links
#   James Garner                                  → 63 links
#   London                                        → 63 links
#   James Woods                                   → 62 links
#   Mickey Rooney                                 → 62 links
#   John C. Frémont                               → 62 links
#   Halle Berry                                   → 62 links
#   Jared Leto                                    → 62 links
#   Chicago (band)                                → 62 links
#   Jon Stewart                                   → 62 links
#   Russell Crowe                                 → 62 links
#   Philip Glass                                  → 61 links
#   Minnesota                                     → 61 links
#   Chiwetel Ejiofor                              → 60 links
#   George W. Bush                                → 60 links
#   John Wayne                                    → 60 links
#   Jay-Z                                         → 59 links
#   Linda Ronstadt                                → 59 links
#   M. Night Shyamalan                            → 59 links
#   Hamilton (musical)                            → 59 links
#   Smokey Robinson                               → 58 links
#   Mahatma Gandhi                                → 58 links
#   Selena                                        → 58 links
#   Johnny Carson                                 → 58 links
#   Steve Bannon                                  → 58 links
#   Indianapolis                                  → 57 links
#   Patsy Cline                                   → 57 links
#   Glenn Gould                                   → 57 links
#   Rudy Giuliani                                 → 57 links
#   Dua Lipa                                      → 57 links
#   Kentucky                                      → 57 links
#   Rachel McAdams                                → 57 links
#   Jennifer Hudson                               → 56 links
#   Ricky Gervais                                 → 56 links
#   Tim Duncan                                    → 56 links
#   Dan Quayle                                    → 56 links
#   Fox News                                      → 56 links
#   Indian Americans                              → 55 links
#   Richard Harris                                → 55 links
#   Gary Sinise                                   → 55 links
#   Little Richard                                → 55 links
#   Calvin Coolidge                               → 55 links
#   Woody Harrelson                               → 54 links
#   Janis Joplin                                  → 54 links
#   William Hurt                                  → 54 links
#   Charles, Prince of Wales                      → 54 links
#   Irving Berlin                                 → 54 links
#   The Incredibles                               → 53 links
#   Henry Mancini                                 → 53 links
#   Coco (2017 film)                              → 53 links
#   Eric Clapton                                  → 53 links
#   Bob Newhart                                   → 53 links
#   Allison Janney                                → 53 links
#   Pixar                                         → 53 links
#   John Goodman                                  → 53 links
#   Tea Party movement                            → 53 links
#   Rose Bowl (stadium)                           → 52 links
#   Michael Flynn                                 → 52 links
#   Julio Iglesias                                → 52 links
#   Warren G. Harding                             → 52 links
#   Donald Trump                                  → 52 links
#   Robert F. Kennedy Memorial Stadium            → 52 links
#   Shailene Woodley                              → 52 links
#   Ed Harris                                     → 52 links
#   Selena Gomez                                  → 51 links
#   George McGovern                               → 51 links
#   Noam Chomsky                                  → 51 links
#   Leopold Stokowski                             → 51 links
#   Manhattan                                     → 51 links
#   Joseph McCarthy                               → 50 links
#   Stan Lee                                      → 50 links
#   William H. Macy                               → 50 links
#   Otto Mann                                     → 50 links
#   Zora Neale Hurston                            → 50 links
#   Melbourne                                     → 50 links
#   Avengers: Infinity War                        → 50 links
#   Aaron Sorkin                                  → 50 links
#   Hubert Humphrey                               → 50 links
#   Björk                                         → 49 links
#   The Hunchback of Notre Dame (1996 film)       → 49 links
#   Academy Award for Best Director               → 49 links
#   Peter Thiel                                   → 49 links
#   50 Cent                                       → 49 links
#   Charles Laughton                              → 49 links
#   John Quincy Adams                             → 49 links
#   Nickelodeon Movies                            → 48 links
#   Dennis Quaid                                  → 48 links
#   Bob Wills                                     → 48 links
#   John Wooden                                   → 48 links
#   Sinclair Broadcast Group                      → 48 links
#   Big Ten Conference                            → 48 links
#   Superman in film                              → 48 links
#   Washington (state)                            → 48 links
#   Ringo Starr                                   → 48 links
#   Republican Party (United States)              → 48 links
#   Bill Walton                                   → 47 links
#   Andrew Jackson                                → 47 links
#   Greta Gerwig                                  → 47 links
#   Fifty Shades of Grey (film)                   → 47 links
#   Maureen O'Hara                                → 47 links
#   Margot Robbie                                 → 47 links
#   Inside Out (2015 film)                        → 47 links
#   Keanu Reeves                                  → 47 links
#   Andrés Segovia                                → 47 links
#   Plácido Domingo                               → 47 links
#   Kiefer Sutherland                             → 47 links
#   Neil Patrick Harris                           → 47 links
#   Annie Lennox                                  → 47 links
#   Kylie Minogue                                 → 46 links
#   Saint Paul, Minnesota                         → 46 links
#   Super Bowl XLIV                               → 46 links
#   Elia Kazan                                    → 46 links
#   Martin Sheen                                  → 46 links
#   Metro-Goldwyn-Mayer                           → 46 links
#   Maine                                         → 46 links
#   Single Ladies (Put a Ring on It)              → 46 links
#   Didier Drogba                                 → 46 links
#   St. Louis                                     → 46 links
#   Cynthia Nixon                                 → 46 links
#   Hubert H. Humphrey Metrodome                  → 46 links
#   The Velvet Underground                        → 46 links
#   Al Franken                                    → 46 links
#   Alfred Molina                                 → 46 links
#   Ann Coulter                                   → 46 links
#   Gangnam Style                                 → 45 links
#   H. P. Lovecraft                               → 45 links
#   Ratatouille (film)                            → 45 links
#   Stephen King                                  → 45 links
#   Phoenix, Arizona                              → 45 links
#   Josh Brolin                                   → 45 links
#   One Direction                                 → 45 links
#   James Gandolfini                              → 45 links
#   John Ford                                     → 45 links
#   Arizona State University                      → 45 links
#   Donny Hathaway                                → 45 links
#   Oh, the Things I Know!                        → 45 links
#   Columbus, Ohio                                → 45 links
#   Peter Falk                                    → 45 links
#   Fearless (Taylor Swift album)                 → 44 links
#   Nathan Lane                                   → 44 links
#   Roger Stone                                   → 44 links
#   Jeremy Renner                                 → 44 links
#   Talking Heads                                 → 44 links
#   Paul Williams (songwriter)                    → 44 links
#   Grandmaster Flash and the Furious Five        → 44 links
#   Jawaharlal Nehru                              → 44 links
#   Oliver North                                  → 44 links
#   The 1989 World Tour                           → 43 links
#   John Terry                                    → 43 links
#   Yul Brynner                                   → 43 links
#   Toy Story 2                                   → 43 links
#   George Jones                                  → 43 links
#   Vanderbilt University                         → 43 links
#   Royals (song)                                 → 43 links
#   Adam McKay                                    → 43 links
#   Manchester City F.C.                          → 43 links
#   Buenos Aires                                  → 43 links
#   Joan Crawford                                 → 43 links
#   Vivien Leigh                                  → 43 links
#   Snow White and the Seven Dwarfs (1937 film)   → 43 links
#   Kansas City, Missouri                         → 43 links
#   Jack Posobiec                                 → 43 links
#   Michael Gambon                                → 42 links
#   Doctor Strange (2016 film)                    → 42 links
#   African American–Jewish relations             → 42 links
#   Harvey Fierstein                              → 42 links
#   Patricia Neal                                 → 42 links
#   The Threepenny Opera                          → 42 links
#   Tiffany Haddish                               → 42 links
#   Fernando Torres                               → 42 links
#   Bad Blood (Taylor Swift song)                 → 42 links
#   Grace Kelly                                   → 42 links
#   Claire Danes                                  → 41 links
#   Kathleen Turner                               → 41 links
#   Darren Criss                                  → 41 links
#   Charles H. Townes                             → 41 links
#   Ellen Page                                    → 41 links
#   Capital city                                  → 41 links
#   Meat Loaf                                     → 41 links
#   Big Hero 6 (film)                             → 41 links
#   Oscar Robertson                               → 41 links
#   Deion Sanders                                 → 41 links
#   Samuel Alito                                  → 41 links
#   Harry Kane                                    → 41 links
#   Gorillaz                                      → 40 links
#   Wreck-It Ralph                                → 40 links
#   Georgia Dome                                  → 40 links
#   Mila Kunis                                    → 40 links
#   Charli XCX                                    → 40 links
#   Ginger Rogers                                 → 40 links
#   Hillsdale College                             → 40 links
#   Edwin Meese                                   → 40 links
#   Grant Hill                                    → 40 links
#   Steve Coogan                                  → 40 links
#   Seth Rogen                                    → 40 links
#   Radio City Music Hall                         → 40 links
#   Metallica                                     → 40 links
#   Kevin Feige                                   → 40 links
#   Bruce Dern                                    → 40 links
#   Hank Azaria                                   → 40 links
#   The Adventures of Tintin (film)               → 39 links
#   2-D (character)                               → 39 links
#   Jude Law                                      → 39 links
#   Milton Friedman                               → 39 links
#   The Princess and the Frog                     → 39 links
#   The Jungle Book 2                             → 39 links
#   Rosamund Pike                                 → 39 links
#   Sharon Stone                                  → 39 links
#   Manchester United F.C.                        → 39 links
#   United States presidential election, 2016     → 39 links
#   Robin Thicke                                  → 39 links
#   Nebraska                                      → 39 links
#   André Previn                                  → 39 links
#   Melbourne Cricket Ground                      → 39 links
#   Jerome Robbins                                → 39 links
#   Bedknobs and Broomsticks                      → 39 links
#   Friedrich Hayek                               → 39 links
#   20th Century Fox                              → 39 links
#   Jimmy Johnson (American football coach)       → 39 links
#   George Strait                                 → 38 links
#   Fleetwood Mac                                 → 38 links
#   Tim Conway                                    → 38 links
#   James and the Giant Peach (film)              → 38 links
#   Gary Payton                                   → 38 links
#   Jon Hamm                                      → 38 links
#   Tim Allen                                     → 38 links
#   Keith Olbermann                               → 38 links
#   Cesc Fàbregas                                 → 38 links
#   Pope Francis                                  → 38 links
#   DC Extended Universe                          → 38 links
#   The Jungle Book (2016 film)                   → 38 links
#   Pete Rose                                     → 38 links
#   Johns Hopkins University                      → 38 links
#   David Jason                                   → 38 links
#   Doc Rivers                                    → 38 links
#   Jamie Bell                                    → 38 links
#   Roy Orbison                                   → 38 links
#   The Producers (musical)                       → 38 links
#   Mark Hughes                                   → 38 links
#   Dave Grohl                                    → 37 links
#   Rio de Janeiro                                → 37 links
#   Roger Staubach                                → 37 links
#   Iowa                                          → 37 links
#   Battlefield Earth (film)                      → 37 links
#   KeyArena                                      → 37 links
#   Louie Louie                                   → 37 links
#   James K. Polk                                 → 37 links
#   Song of the South                             → 37 links
#   Fergie (singer)                               → 37 links
#   Christian Slater                              → 37 links
#   Dodge City, Kansas                            → 37 links
#   Klaus Maria Brandauer                         → 37 links
#   Blank Space                                   → 37 links
#   NBA All-Rookie Team                           → 37 links
#   North Carolina                                → 37 links
#   The Federalist (website)                      → 37 links
#   Ralph Sampson                                 → 37 links
#   Flea (musician)                               → 37 links
#   Thomas More Law Center                        → 37 links
#   Greta Garbo                                   → 37 links
#   Moana (2016 film)                             → 37 links
#   Cinderella (1950 film)                        → 36 links
#   Mary Pickford                                 → 36 links
#   City of Manchester Stadium                    → 36 links
#   Rango (2011 film)                             → 36 links
#   Thor: Ragnarok                                → 36 links
#   Hartford, Connecticut                         → 36 links
#   Mauritius                                     → 36 links
#   Apple Inc.                                    → 36 links
#   Carlo Ancelotti                               → 36 links
#   Indian National Congress                      → 36 links
#   Old Trafford                                  → 36 links
#   Mexico City                                   → 36 links
#   Fascism                                       → 36 links
#   Paula Abdul                                   → 36 links
#   A Midsummer Night's Dream                     → 36 links
#   Priyanka Chopra                               → 36 links
#   Pat Boone                                     → 36 links
#   Oliver Cromwell                               → 36 links
#   Elizabeth Olsen                               → 35 links
#   Sarah Jessica Parker                          → 35 links
#   The Aristocats                                → 35 links
#   I Will Always Love You                        → 35 links
#   Catherine O'Hara                              → 35 links
#   Pet Shop Boys                                 → 35 links
#   Roger Miller                                  → 35 links
#   University of California, Berkeley            → 35 links
#   Winona Ryder                                  → 35 links
#   Gwen Stefani                                  → 35 links
#   Portland, Oregon                              → 35 links
#   Super Bowl XLVIII                             → 35 links
#   Mikhail Baryshnikov                           → 35 links
#   Shania Twain                                  → 35 links
#   Rio Ferdinand                                 → 35 links
#   Taki's Magazine                               → 35 links
#   Arctic Monkeys                                → 35 links
#   Bobby Moore                                   → 35 links
#   Sergio Agüero                                 → 35 links
#   Seoul                                         → 35 links
#   Marilyn Monroe                                → 35 links
#   Scooby-Doo                                    → 34 links
#   Adam Smith                                    → 34 links
#   Dave Chappelle                                → 34 links
#   Marvel Studios                                → 34 links
#   Iron Man 3                                    → 34 links
#   NSYNC                                         → 34 links
#   United States Navy                            → 34 links
#   Los Angeles Lakers                            → 34 links
#   Troy Aikman                                   → 34 links
#   Northwestern University                       → 34 links
#   Studio 54                                     → 34 links
#   Avatar (2009 film)                            → 34 links
#   Rudyard Kipling                               → 34 links
#   Iker Casillas                                 → 34 links
#   Barry Manilow                                 → 34 links
#   Empire State Building                         → 34 links
#   Andrés Iniesta                                → 34 links
#   Don Henley                                    → 34 links
#   Jean Hersholt                                 → 34 links
#   Aristotle                                     → 34 links
#   Hannah Arendt                                 → 34 links
#   Imelda Staunton                               → 34 links
#   Edward Teller                                 → 34 links
#   Ted Williams                                  → 34 links
#   Bolt (2008 film)                              → 34 links
#   Vlade Divac                                   → 34 links
#   Tarzan (1999 film)                            → 34 links
#   Pontiac Silverdome                            → 34 links
#   Palermo                                       → 34 links
#   Tangled                                       → 34 links
#   Jukebox musical                               → 34 links
#   Robert Kraft                                  → 34 links
#   Las Vegas Sands                               → 33 links
#   Amy Madigan                                   → 33 links
#   Sandy Koufax                                  → 33 links
#   The Red Tour                                  → 33 links
#   Julia Stiles                                  → 33 links
#   Germany                                       → 33 links
#   Louis Brandeis                                → 33 links
#   Cars 3                                        → 33 links
#   Las Vegas Strip                               → 33 links
#   Waiting for Godot                             → 33 links
#   West Ham United F.C.                          → 33 links
#   Stardust Resort and Casino                    → 33 links
#   Sergio Ramos                                  → 33 links
#   The SpongeBob SquarePants Movie               → 33 links
#   India                                         → 33 links
#   Indiana Pacers                                → 33 links
#   World War II                                  → 33 links
#   Nike Hypervenom                               → 33 links
#   Chris Mullin (basketball)                     → 33 links
#   Amar'e Stoudemire                             → 33 links
#   Edgar Allan Poe                               → 33 links
#   Capital District, New York                    → 33 links
#   The AXIS                                      → 33 links
#   Peter Schmeichel                              → 33 links
#   Shakira                                       → 33 links
#   East South Central States                     → 33 links
#   Westminster Abbey                             → 33 links
#   Kevin Bacon                                   → 33 links
#   Tom Osborne                                   → 33 links
#   Wes Anderson                                  → 33 links
#   The Star-Spangled Banner                      → 33 links
#   Curt Schilling                                → 33 links
#   Leslie Bricusse                               → 33 links
#   Mark Strong                                   → 33 links
#   Air National Guard                            → 33 links
#   United States Naval Academy                   → 33 links
#   North Las Vegas, Nevada                       → 32 links
#   Tupac Shakur                                  → 32 links
#   Adrian Dantley                                → 32 links
#   Clark County, Nevada                          → 32 links
#   Edward James Olmos                            → 32 links
#   Rascal Flatts                                 → 32 links
#   Deadpool 2                                    → 32 links
#   55th Academy Awards                           → 32 links
#   Chris Martin                                  → 32 links
#   Chris Tucker                                  → 32 links
#   Las Vegas Valley                              → 32 links
#   The Forum Shops at Caesars                    → 32 links
#   Thelma Schoonmaker                            → 32 links
#   Dan Aykroyd                                   → 32 links
#   Virginia Madsen                               → 32 links
#   Barry Keoghan                                 → 32 links
#   Howard the Duck (film)                        → 32 links
#   Luis Walter Alvarez                           → 32 links
#   Attack on Pearl Harbor                        → 32 links
#   Nottingham Forest F.C.                        → 32 links
#   MGM Grand Garden Arena                        → 32 links
#   Michael Giacchino                             → 32 links
#   A Head Full of Dreams Tour                    → 32 links
#   The Everly Brothers                           → 32 links
#   Owen Wilson                                   → 32 links
#   The Forum (Inglewood, California)             → 32 links
#   Elvis Costello                                → 32 links
#   Tim Hardaway                                  → 32 links
#   Georg Solti                                   → 31 links
#   Naismith Memorial Basketball Hall of Fame     → 31 links
#   Lansing, Michigan                             → 31 links
#   Daredevil (film)                              → 31 links
#   George Armstrong Custer                       → 31 links
#   Northwestern United States                    → 31 links
#   Billy West                                    → 31 links
#   American Civil War                            → 31 links
#   Cry Me a River (Justin Timberlake song)       → 31 links
#   Raleigh, North Carolina                       → 31 links
#   Man of Steel (film)                           → 31 links
#   Yehudi Menuhin                                → 31 links
#   Twelfth Night                                 → 31 links
#   Black Panther Party                           → 31 links
#   Morocco                                       → 31 links
#   Sheldon Harnick                               → 31 links
#   Dartmouth College                             → 31 links
#   Meg Ryan                                      → 31 links
#   Liverpool F.C.                                → 31 links
#   Ray Winstone                                  → 31 links
#   Batman (1989 film)                            → 31 links
#   Paolo Maldini                                 → 31 links
#   Strictly Come Dancing (series 9)              → 31 links
#   Nobel Peace Prize Concert                     → 31 links
#   Nationalism                                   → 31 links
#   Chester A. Arthur                             → 31 links
#   Allentown, Pennsylvania                       → 31 links
#   Cliff Richard                                 → 31 links
#   Arvydas Sabonis                               → 31 links
#   Boston University                             → 30 links
#   Reno, Nevada                                  → 30 links
#   Twenty One Pilots                             → 30 links
#   Alexander Graham Bell                         → 30 links
#   Pete Docter                                   → 30 links
#   Joseph Stalin                                 → 30 links
#   Desert Inn                                    → 30 links
#   Emmanuel Macron                               → 30 links
#   Spider-Man 2                                  → 30 links
#   The Black Cauldron (film)                     → 30 links
#   Bernard King                                  → 30 links
#   God Save the Queen                            → 30 links
#   Disney Renaissance                            → 30 links
#   Keith Jackson                                 → 30 links
#   Lady and the Tramp                            → 30 links
#   Jennifer Saunders                             → 30 links
#   Terrence Malick                               → 30 links
#   Gus Van Sant                                  → 30 links
#   Jacques Villeneuve                            → 30 links
#   Loretta Young                                 → 30 links
#   Schutzstaffel                                 → 30 links
#   United States Army                            → 30 links
#   Nick Cave                                     → 30 links
#   Michael Schumacher                            → 30 links
#   Suffolk County, New York                      → 30 links
#   Macalester College                            → 30 links
#   New York Yankees                              → 30 links
#   New Frontier Hotel and Casino                 → 30 links
#   T-Mobile Arena                                → 30 links
#   Deep Purple                                   → 29 links
#   X-Men (film series)                           → 29 links
#   Rafael Benítez                                → 29 links
#   Brisbane                                      → 29 links
#   Nine (musical)                                → 29 links
#   Ford Motor Company                            → 29 links
#   Diane Kruger                                  → 29 links
#   Mike Tyson                                    → 29 links
#   Henrik Larsson                                → 29 links
#   Mack Brown                                    → 29 links
#   Edward VIII                                   → 29 links
#   Doc Hudson                                    → 29 links
#   Howard Hughes                                 → 29 links
#   Paul Anka                                     → 29 links
#   Joe Walsh                                     → 29 links
#   Machine Gun Kelly (rapper)                    → 29 links
#   Camping World Stadium                         → 29 links
#   Aston Villa F.C.                              → 29 links
#   2011 UEFA Champions League Final              → 29 links
#   Darrell Royal                                 → 29 links
#   Jason Sudeikis                                → 29 links
#   The Venetian Las Vegas                        → 29 links
#   Style (Taylor Swift song)                     → 29 links
#   Harry Potter and the Prisoner of Azkaban (fil → 29 links
#   Shane Warne                                   → 29 links
#   Mandy Moore                                   → 29 links
#   Boeing B-17 Flying Fortress                   → 29 links
#   Felicity Jones                                → 29 links
#   Henry Wadsworth Longfellow                    → 29 links
#   Rock am Ring and Rock im Park                 → 29 links
#   Halsey (singer)                               → 28 links
#   Franz Schubert                                → 28 links
#   Super Bowl XLI                                → 28 links
#   Tears in Heaven                               → 28 links
#   Miracle on Ice                                → 28 links
#   Elliot Goldenthal                             → 28 links
#   Dred Scott v. Sandford                        → 28 links
#   Deadwood, South Dakota                        → 28 links
#   Chuck Daly                                    → 28 links
#   Billy Donovan                                 → 28 links
#   Blade Runner                                  → 28 links
#   Roseanne                                      → 28 links
#   Freddie Mercury                               → 28 links
#   Richard Griffiths                             → 28 links
#   United States Armed Forces                    → 28 links
#   Yerevan                                       → 28 links
#   Otto von Bismarck                             → 28 links
#   The Palazzo                                   → 28 links
#   Lewis Cass                                    → 28 links
#   Little Mix                                    → 28 links
#   David de Gea                                  → 28 links
#   Satire                                        → 28 links
#   Fallingwater                                  → 28 links
#   Cole Younger                                  → 28 links
#   Bambi II                                      → 28 links
#   Queens Park Rangers F.C.                      → 28 links
#   Mark McGwire                                  → 28 links
#   Roy Clark                                     → 28 links
#   Roald Dahl                                    → 28 links
#   Jimmy Kimmel                                  → 28 links
#   MGM Grand Las Vegas                           → 28 links
#   Winchester, Nevada                            → 28 links
#   Klemens von Metternich                        → 28 links
#   Quanah Parker                                 → 28 links
#   Lawrence, Kansas                              → 28 links
#   Roman Republic                                → 28 links
#   Kevin Smith                                   → 28 links
#   Rogue One                                     → 28 links
#   The Beatles (album)                           → 28 links
#   Ricky Skaggs                                  → 28 links
#   ICAO airport code                             → 28 links
#   Henry Selick                                  → 28 links
#   Flamingo Las Vegas                            → 28 links
#   George Curzon, 1st Marquess Curzon of Kedlest → 28 links
#   Trieste                                       → 28 links
#   Detroit Pistons                               → 28 links
#   Sarah Polley                                  → 28 links
#   Toronto Raptors                               → 28 links
#   Pac-12 Conference                             → 28 links
#   Miranda Lambert                               → 28 links
#   Millard Fillmore                              → 28 links
#   Ghana                                         → 28 links
#   Taylor Swift videography                      → 27 links
#   Muhammad                                      → 27 links
#   Roy Jenkins                                   → 27 links
#   Benjamin Britten                              → 27 links
#   Abdullah II of Jordan                         → 27 links
#   Mario Balotelli                               → 27 links
#   Space Jam                                     → 27 links
#   Dawn French                                   → 27 links
#   Gregg Popovich                                → 27 links
#   Charles II of England                         → 27 links
#   Hulk (comics)                                 → 27 links
#   Alt-right                                     → 27 links
#   Paul Scholes                                  → 27 links
#   Kim Cattrall                                  → 27 links
#   John Wall (basketball)                        → 27 links
#   Fox Broadcasting Company                      → 27 links
#   The SpongeBob Movie: Sponge Out of Water      → 27 links
#   Grand Canal Shoppes                           → 27 links
#   Cato Institute                                → 27 links
#   Dr. Dre                                       → 27 links
#   Milwaukee Bucks                               → 27 links
#   UFC Tonight                                   → 27 links
#   Band on the Run                               → 27 links
#   Toledo, Ohio                                  → 27 links
#   Ultimate Fighting Championship                → 27 links
#   Leicester City F.C.                           → 27 links
#   William Westmoreland                          → 27 links
#   Damian Lillard                                → 27 links
#   Chien-Shiung Wu                               → 27 links
#   John Candy                                    → 27 links
#   X (Ed Sheeran album)                          → 27 links
#   Patsy Mink                                    → 27 links
#   The Bronx                                     → 27 links
#   St. Patrick's Cathedral (Manhattan)           → 27 links
#   Grand Rapids, Michigan                        → 27 links
#   Palms Casino Resort                           → 27 links
#   Kingdom of England                            → 27 links
#   Spectre (2015 film)                           → 27 links
#   59th Primetime Emmy Awards                    → 27 links
#   Karl-Anthony Towns                            → 27 links
#   Javier Hernández                              → 27 links
#   Harlem Renaissance                            → 27 links
#   Togo                                          → 27 links
#   Erykah Badu                                   → 27 links
#   I Knew You Were Trouble                       → 27 links
#   Phoenix Suns                                  → 27 links
#   Malaysia Airlines                             → 27 links
#   Suharto                                       → 27 links
#   Oscar Hammerstein II                          → 27 links
#   Aaron Judge                                   → 27 links
#   George Segal                                  → 27 links
#   Roque Santa Cruz                              → 26 links
#   Alexander Hamilton                            → 26 links
#   Henry VIII of England                         → 26 links
#   Pomona College                                → 26 links
#   Kim Novak                                     → 26 links
#   Lil Jon                                       → 26 links
#   Jim Lovell                                    → 26 links
#   Sam Bradford                                  → 26 links
#   Michael Steele                                → 26 links
#   Franz Liszt                                   → 26 links
#   Napoleonic Wars                               → 26 links
#   Dimitar Berbatov                              → 26 links
#   Thom Yorke                                    → 26 links
#   High Plains (United States)                   → 26 links
#   Daniel Inouye                                 → 26 links
#   Tom and Jerry                                 → 26 links
#   Target Corporation                            → 26 links
#   La La Land (film)                             → 26 links
#   Megan Fox                                     → 26 links
#   Baker Mayfield                                → 26 links
#   Jessica Alba                                  → 26 links
#   Mark Aguirre                                  → 26 links
#   Bob Stoops                                    → 26 links
#   CNN                                           → 26 links
#   Bogotá                                        → 26 links
#   Super Bowl XXXIII                             → 26 links
#   Richard B. Spencer                            → 26 links
#   Twilight (2008 film)                          → 26 links
#   Rain (entertainer)                            → 26 links
#   Paul Bettany                                  → 26 links
#   São Paulo                                     → 26 links
#   John Ruskin                                   → 26 links
#   Sesame Street                                 → 26 links
#   Isla Fisher                                   → 26 links
#   Walt Disney Pictures                          → 26 links
#   Jean Sibelius                                 → 26 links
#   Lucy Liu                                      → 26 links
#   Washington and Lee University                 → 26 links
#   Nickelodeon                                   → 26 links
#   Peter Asher                                   → 26 links
#   United States Congress                        → 26 links
#   Eastern Front (World War II)                  → 26 links
#   Royal Shakespeare Company                     → 26 links
#   Eric Dickerson                                → 26 links
#   Rutgers University                            → 26 links
#   Titus Andronicus                              → 26 links
#   Zimbabwe                                      → 26 links
#   Valley View Casino Center                     → 26 links
#   South Park                                    → 26 links
#   Slovenia                                      → 26 links
#   Equatorial Guinea                             → 26 links
#   Mike Patton                                   → 26 links
#   Barry Switzer                                 → 25 links
#   United Arab Emirates                          → 25 links
#   Animal House                                  → 25 links
#   Thandie Newton                                → 25 links
#   Don Williams                                  → 25 links
#   Kurt Weill                                    → 25 links
#   University of Oklahoma                        → 25 links
#   Federal Hall                                  → 25 links
#   Justice League Unlimited                      → 25 links
#   Andy Samberg                                  → 25 links
#   Encore Las Vegas                              → 25 links
#   Missouri River                                → 25 links
#   Steve McQueen                                 → 25 links
#   Operation Paperclip                           → 25 links
#   Chrysler Building                             → 25 links
#   Narendra Modi                                 → 25 links
#   Islip, New York                               → 25 links
#   Giuseppe Verdi                                → 25 links
#   Grimsby Town F.C.                             → 25 links
#   Emma Roberts                                  → 25 links
#   MTV Europe Music Award for Best Song          → 25 links
#   Border states (American Civil War)            → 25 links
#   Edwin van der Sar                             → 25 links
#   Valentine's Day (2010 film)                   → 25 links
#   Blondie (band)                                → 25 links
#   Eddie Izzard                                  → 25 links
#   Jared Harris                                  → 25 links
#   Miss Universe 2010                            → 25 links
#   Hawaiian Airlines                             → 25 links
#   Planet Hollywood Las Vegas                    → 25 links
#   Ed Wood                                       → 25 links
#   Mary Wollstonecraft                           → 25 links
#   Birmingham campaign                           → 25 links
#   Portland Trail Blazers                        → 25 links
#   Libya                                         → 25 links
#   Vatican City                                  → 25 links
#   Robert Smith (musician)                       → 25 links
#   Sara Evans                                    → 25 links
#   Imagine Dragons                               → 25 links
#   Kurt Cobain                                   → 25 links
#   Hôtel de Crillon                              → 25 links
#   Charles I of England                          → 25 links
#   Adam Guettel                                  → 25 links
#   300 (film)                                    → 25 links
#   Muammar Gaddafi                               → 25 links
#   Hertfordshire                                 → 25 links
#   Finnair                                       → 25 links
#   Red (Taylor Swift song)                       → 25 links
#   Hank Aaron                                    → 25 links
#   2012 NBA draft                                → 25 links
#   Natasha Lyonne                                → 25 links
#   SLS station                                   → 25 links
#   Bette Davis Eyes                              → 25 links
#   2013 NBA draft                                → 25 links
#   Leslie Caron                                  → 25 links
#   Barry Bonds                                   → 25 links
#   Russell T Davies                              → 25 links
#   Saif Ali Khan                                 → 25 links
#   Nicki Minaj videography                       → 25 links
#   Cambodia                                      → 24 links
#   The End Tour                                  → 24 links
#   Byronic hero                                  → 24 links
#   Edmonton                                      → 24 links
#   10 Downing Street                             → 24 links
#   Circus Circus Las Vegas                       → 24 links
#   The Office (U.S. TV series)                   → 24 links
#   Shinzō Abe                                    → 24 links
#   Florence                                      → 24 links
#   Ion Antonescu                                 → 24 links
#   Ray Wilkins                                   → 24 links
#   Blade Runner 2049                             → 24 links
#   Sri Lanka                                     → 24 links
#   Bob Barker                                    → 24 links
#   Danai Gurira                                  → 24 links
#   François Truffaut                             → 24 links
#   Golden Globe Award for Best Animated Feature  → 24 links
#   Tony Blair                                    → 24 links
#   George V                                      → 24 links
#   Henry V of England                            → 24 links
# ...
#   Hotcourses Group                              ← 0 links
#   Oksana Lada                                   ← 0 links
#   Allium robinsonii                             ← 0 links
#   Gangwon State University                      ← 0 links
#   Le'Bryan Nash                                 ← 0 links
#   Move Under Ground                             ← 0 links
#   Foster's rule                                 ← 0 links
#   HMS Sussex (1693)                             ← 0 links
#   Gerd B. Müller                                ← 0 links
#   Jo Ann Terry                                  ← 0 links
#   Pretty Please                                 ← 0 links
#   Rifda Irfanaluthfi                            ← 0 links
#   H. Frank Carey Junior-Senior High School      ← 0 links
#   John Bruce Yeh                                ← 0 links
#   The Elephant Man (film)                       ← 0 links
#   Highland (Capital MetroRail station)          ← 0 links
#   Sameera Perera                                ← 0 links
#   2017 Canadian Olympic Curling Trials          ← 0 links
#   Minneapolis mayoral election, 2009            ← 0 links
#   Kenn Scott                                    ← 0 links
#   Bruno Olbrycht                                ← 0 links
#   A Company of Swans                            ← 0 links
#   Suicide Squad (film)                          ← 0 links
#   James W. and Anne Smith Phyfe Estate          ← 0 links
#   2011 Adelaide Football Club season            ← 0 links
#   Márcio Borges                                 ← 0 links
#   Deep Pal                                      ← 0 links
#   Ahmad Khormali                                ← 0 links
#   Showbiz Tycoon                                ← 0 links
#   Dorothy Nelkin                                ← 0 links
#   Isaac K. Funk                                 ← 0 links
#   Pete Elezovic                                 ← 0 links
#   Edward J. Samp                                ← 0 links
#   Tommy Gunn (toy)                              ← 0 links
#   14th Lumières Awards                          ← 0 links
#   WIND (Italy)                                  ← 0 links
#   Tom Manning (comics)                          ← 0 links
#   Amundsen Bay                                  ← 0 links
#   Hodgson v Marks                               ← 0 links
#   Lest we forget (phrase)                       ← 0 links
#   Steve Carter (rugby league)                   ← 0 links
#   Christmas Bells (advertisement)               ← 0 links
#   Joe Kasher                                    ← 0 links
#   Spokestoon                                    ← 0 links
#   Boomerang (Southeast Asia)                    ← 0 links
#   2010 Mnet Asian Music Awards                  ← 0 links
#   Iconic (song)                                 ← 0 links
#   Marc Abaya                                    ← 0 links
#   John Fischetti                                ← 0 links
#   Ana-Maria Yanakieva                           ← 0 links
#   Enslaved (band)                               ← 0 links
#   Azor Betts                                    ← 0 links
#   My Son (film)                                 ← 0 links
#   Millbrook, Philadelphia                       ← 0 links
#   2014 Charles Sturt Adelaide International     ← 0 links
#   Pelegrina Pastorino                           ← 0 links
#   Battle of Watling Street                      ← 0 links
#   A Tribute to Judas Priest: Legends of Metal   ← 0 links
#   Comic Court                                   ← 0 links
#   Democracy Day (United States)                 ← 0 links
#   Hacienda (resort)                             ← 0 links
#   Huldrehatten                                  ← 0 links
#   SLS station                                   ← 0 links
#   Enugu                                         ← 0 links
#   Kevin Byrne (politician)                      ← 0 links
#   Nobia A. Franklin                             ← 0 links
#   Cat Sandion                                   ← 0 links
#   Lorton station (VRE)                          ← 0 links
#   Huntington Mall                               ← 0 links
#   Svetlana Radzivil                             ← 0 links
#   Elwyn McRoy                                   ← 0 links
#   Cabalva (1811 EIC ship)                       ← 0 links
#   Noura                                         ← 0 links
#   Billy Henry                                   ← 0 links
#   Operation Aloha (album)                       ← 0 links
#   Light It Up (soundtrack)                      ← 0 links
#   Bonfire (album)                               ← 0 links
#   1981 U.S. Clay Court Championships            ← 0 links
#   Roger Morris (engineer)                       ← 0 links
#   Coffee cherry tea                             ← 0 links
#   Eeyou Istchee James Bay Territory             ← 0 links
#   Videoscandals                                 ← 0 links
#   Days of America                               ← 0 links
#   Revolt of the Beavers                         ← 0 links
#   The Underdog (film)                           ← 0 links
#   C/2008 T2 (Cardinal)                          ← 0 links
#   Choctaw Youth Movement                        ← 0 links
#   I Am Gloria Gaynor                            ← 0 links
#   Gregg Wager                                   ← 0 links
#   Terry Kilgore                                 ← 0 links
#   Mathilde Lemoine                              ← 0 links
#   Jack Baldwin (racing driver)                  ← 0 links
#   Freeway Airport                               ← 0 links
#   Mississippi mud pie                           ← 0 links
#   Rabinjan                                      ← 0 links
#   Peter Charanis                                ← 0 links
#   Panadol night                                 ← 0 links
#   Harold E. Bradshaw                            ← 0 links
#   USS Barataria (AVP-33)                        ← 0 links
#   Rose Batiste                                  ← 0 links
#   Gonzalo López-Gallego                         ← 0 links
#   Lee Min-ho (actor, born 1987)                 ← 0 links
#   Sovereign (British coin)                      ← 0 links
#   Rosemary West                                 ← 0 links
#   Keith Hetrick                                 ← 0 links
#   Anna B. Sheppard                              ← 0 links
#   Problem (Natalia Kills song)                  ← 0 links
#   Mabel Murphy Smythe-Haith                     ← 0 links
#   Cosimo Ulivelli                               ← 0 links
#   Lykele Faber                                  ← 0 links
#   To the End of the Earth                       ← 0 links
#   Craig Lindfield                               ← 0 links
#   2014 Kids' Choice Sports Awards               ← 0 links
#   Hotels and Catering (constituency)            ← 0 links
#   Unscandal                                     ← 0 links
#   James Matheson (composer)                     ← 0 links
#   Augusto Solari                                ← 0 links
#   Vincent Kling (translator)                    ← 0 links
#   COM LAG (2plus2isfive)                        ← 0 links
#   Winsingad                                     ← 0 links
#   5BBB                                          ← 0 links
#   Vladimir Shainsky                             ← 0 links
#   Isa (album)                                   ← 0 links
#   Alien Intelligence (Palladium Books)          ← 0 links
#   Complicated (Rihanna song)                    ← 0 links
#   Yakubu II                                     ← 0 links
#   Harrods Creek, Louisville                     ← 0 links
#   Joseph McMoneagle                             ← 0 links
#   Nicktoons (UK and Ireland)                    ← 0 links
#   Spry Vegetable Shortening                     ← 0 links
#   Nicole de Boer                                ← 0 links
#   A Push and a Shove                            ← 0 links
#   2017 Men's Asian Individual Squash Championsh ← 0 links
#   Nosedive                                      ← 0 links
#   Roy Kinneer Patteson, Jr.                     ← 0 links
#   19th Lumières Awards                          ← 0 links
#   Jean Schlumberger (jewelry designer)          ← 0 links
#   The Crusades (film)                           ← 0 links
#   Willie the Kid (rapper)                       ← 0 links
#   Otryadyn Gündegmaa                            ← 0 links
#   Children of a Lesser God                      ← 0 links
#   Real Damage                                   ← 0 links
#   Andrew Stockdale                              ← 0 links
#   The Drop (film)                               ← 0 links
#   Lake George, New York                         ← 0 links
#   Chang Ucchin                                  ← 0 links
#   Anna Maria Borowska                           ← 0 links
#   Monty Python's Life of Brian (album)          ← 0 links
#   Mississippi Opera                             ← 0 links
#   Tajamika Paxton                               ← 0 links
#   Richard Bedford                               ← 0 links
#   Lost Lettermen                                ← 0 links
#   Trinity (TV series)                           ← 0 links
#   Artie Maddicks                                ← 0 links
#   Old School (film)                             ← 0 links
#   Phrase structure grammar                      ← 0 links
#   State of the Black Union                      ← 0 links
#   Take It Like a Man (Michelle Wright song)     ← 0 links
#   David Johnston (politician)                   ← 0 links
#   Sam Totman                                    ← 0 links
#   Tura Beach, New South Wales                   ← 0 links
#   Spring-Heeled Jim                             ← 0 links
#   Giulio Sabino                                 ← 0 links
#   1977 Convair CV-240 crash                     ← 0 links
#   Panda (song)                                  ← 0 links
#   Mokolea Rock                                  ← 0 links
#   No One Would Tell                             ← 0 links
#   Feels Like Home (Chantal Kreviazuk song)      ← 0 links
#   Erich Raeder resignation and later            ← 0 links
#   Paul Bunyan Land                              ← 0 links
#   Roger Williams (soldier)                      ← 0 links
#   United States Senate election in Oklahoma, 19 ← 0 links
#   Buliao qing (song)                            ← 0 links
#   Jean Byron                                    ← 0 links
#   Anne Maddocks                                 ← 0 links
#   Josefina Villamil Tinajero                    ← 0 links
#   Hawaiian tropical dry forests                 ← 0 links
#   A Separate Peace (film)                       ← 0 links
#   Yong Duk Jhun                                 ← 0 links
#   English National Opera commissions and premie ← 0 links
#   What Up with That                             ← 0 links
#   Settle for More                               ← 0 links
#   Indian vice-presidential election, 2012       ← 0 links
#   2014 Texas Southern Tigers football team      ← 0 links
#   Ettore Forti                                  ← 0 links
#   People's Choice Classic                       ← 0 links
#   3005                                          ← 0 links
#   Breach of Promise (film)                      ← 0 links
#   Nelly Ben-Or                                  ← 0 links
#   R Adams Cowley                                ← 0 links
#   Lowry Hotel                                   ← 0 links
#   Heaven Is a Playground (film)                 ← 0 links
#   Closer to the Sun (Guy Sebastian album)       ← 0 links
#   Tod of the Fens                               ← 0 links
#   Mahler Symphony No. 8 discography             ← 0 links
#   Duane Swank                                   ← 0 links
#   2013–14 Eastern Kentucky Colonels basketball  ← 0 links
#   Mazda Roadpacer AP                            ← 0 links
#   527 Euryanthe                                 ← 0 links
#   Teeth (film)                                  ← 0 links
#   Macao (film)                                  ← 0 links
#   Agalassoi                                     ← 0 links
#   Michel Dubois (ice hockey)                    ← 0 links
#   Harriet Ann Jacobs                            ← 0 links
#   Yuddham                                       ← 0 links
#   Thomas C. Mann                                ← 0 links
#   Jacques Mathou                                ← 0 links
#   Curly Ray Cline                               ← 0 links
#   Trevor Prangley                               ← 0 links
#   I'Anson baronets                              ← 0 links
#   Toyota Owners 400                             ← 0 links
#   A Common Man (film)                           ← 0 links
#   It Takes a Family                             ← 0 links
#   Abbey of Saint-Étienne, Caen                  ← 0 links
#   Sidney Hall (film)                            ← 0 links
#   Richard Miniter                               ← 0 links
#   King of Queens (album)                        ← 0 links
#   Verrazano-Narrows Bridge                      ← 0 links
#   Micronesian parliamentary election, 1985      ← 0 links
#   Quality Cafe (diner)                          ← 0 links
#   Jammu and Kashmir                             ← 0 links
#   Cross-Cultural Dance Resources                ← 0 links
#   Giles Hussey                                  ← 0 links
#   Saint-Jean-Chrysostome, Lévis, Quebec         ← 0 links
#   Rastelli procedure                            ← 0 links
#   The Cab discography                           ← 0 links
#   Elora Danan                                   ← 0 links
#   Tjeerd Korf                                   ← 0 links
#   Fanna                                         ← 0 links
#   Randolph Bromery                              ← 0 links
#   Doloroso, Mississippi                         ← 0 links
#   Sea Jet                                       ← 0 links
#   United Nations Security Council Resolution 72 ← 0 links
#   Phaeochlaena costaricensis                    ← 0 links
#   Episode 8 (Twin Peaks)                        ← 0 links
#   Raghu Ram                                     ← 0 links
#   Hans Loewald                                  ← 0 links
#   In the Name of the Father (film)              ← 0 links
#   Abdiel Vázquez                                ← 0 links
#   Shades of Gray (Reeder novel)                 ← 0 links
#   Eastsideridaz                                 ← 0 links
#   Constantin Brătescu                           ← 0 links
#   Mount Vernon City School District             ← 0 links
#   Imi Mqourn                                    ← 0 links
#   Onesimus (Boston slave)                       ← 0 links
#   Jyoti Chetty                                  ← 0 links
#   Mercy Drive                                   ← 0 links
#   John of Arsuf                                 ← 0 links
#   The Sacrifice                                 ← 0 links
#   KBSO                                          ← 0 links
#   Dorian Lord                                   ← 0 links
#   2011 Super Copa Telcel                        ← 0 links
#   Zuigan-ji                                     ← 0 links
#   Jolanta Dičkutė                               ← 0 links
#   Thomas Gregory (actor)                        ← 0 links
#   Right Now (book)                              ← 0 links
#   Tom Clegg (actor)                             ← 0 links
#   O (film)                                      ← 0 links
#   Svensk Hyllningsfest                          ← 0 links
#   Marshall King                                 ← 0 links
#   Paris by Night 83                             ← 0 links
#   Louisiana Saturday Night                      ← 0 links
#   Flybe                                         ← 0 links
#   Margaret MacDonald (visionary)                ← 0 links
#   Tinikling                                     ← 0 links
#   James MacGregor (moderator)                   ← 0 links
#   The Calling                                   ← 0 links
#   Turbidimetric inhibition immunoassay          ← 0 links
#   Rhamnus purshiana                             ← 0 links
#   Crespo, Entre Ríos                            ← 0 links
#   Rafael Ynoa                                   ← 0 links
#   Miss Perú 2010                                ← 0 links
#   Prem Mathur                                   ← 0 links
#   Carrington House                              ← 0 links
#   Yeo Bum-kyu                                   ← 0 links

# %% [markdown]
# ---
# ## Step 3 — Visualize the Hyperlink Graph

# %%
# Only visualize if there are edges to show
if graph.number_of_edges() == 0:
    print('No edges in graph — all corpus pages are isolated nodes.')
    print('This can happen with a small corpus where pages do not link to each other.')
else:
    fig, ax = plt.subplots(figsize=(13, 8))

    # Layout
    pos = nx.spring_layout(graph, seed=42, k=2.5)

    # Node sizes proportional to in-degree (hub pages are larger)
    in_degrees   = dict(graph.in_degree())
    node_sizes   = [300 + in_degrees[n] * 200 for n in graph.nodes()]

    # Draw
    nx.draw_networkx_nodes(graph, pos, node_size=node_sizes,
                           node_color='steelblue', alpha=0.85, ax=ax)
    nx.draw_networkx_labels(graph, pos, font_size=7, ax=ax)
    nx.draw_networkx_edges(graph, pos, arrows=True, arrowsize=12,
                           edge_color='gray', alpha=0.5,
                           connectionstyle='arc3,rad=0.1', ax=ax)

    ax.set_title('Wikipedia Hyperlink Graph\n(node size = in-degree, arrows = link direction)',
                 fontsize=12)
    ax.axis('off')
    plt.tight_layout()
    plt.savefig(str(DATA_DIR / 'hyperlink_graph.png'), dpi=100, bbox_inches='tight')
    plt.show()
    print('Saved: data/hyperlink_graph.png')
# Out:
# Saved: data/hyperlink_graph.png

# %% [markdown]
# ---
# ## Step 4 — 1-Hop Graph Expansion
#
# After FAISS retrieves the initial top-k pages, we **expand** the result set by walking one hop in the graph:
#
# 1. For each retrieved page, collect all pages it **links to** (successors) and **pages that link to it** (predecessors)
# 2. Keep only pages that are in the corpus and NOT already retrieved
# 3. Re-rank the candidates by query similarity (FAISS again, on this small set)
# 4. Take the top `expand_k` new pages
#
# > We expand in BOTH directions (out-edges and in-edges) to capture co-reference relationships.

# %%
# We need embed/retrieve for HyperRAG — define them here (same as notebooks 02 & 03)
MODEL_NAME = 'sentence-transformers/all-MiniLM-L6-v2'
_model = None

def get_model():
    global _model
    if _model is None:
        print(f'Loading {MODEL_NAME} ...')
        _model = SentenceTransformer(MODEL_NAME)
        print('Model ready.')
    return _model

def embed_texts(texts):
    model = get_model()
    vecs  = model.encode(texts, show_progress_bar=len(texts) > 20, convert_to_numpy=True)
    vecs  = vecs.astype('float32')
    faiss.normalize_L2(vecs)
    return vecs

def build_index(corpus):
    print(f'Building index for {len(corpus)} pages ...')
    vecs = embed_texts([p['text'] for p in corpus])
    idx  = faiss.IndexFlatIP(vecs.shape[1])
    idx.add(vecs)
    print(f'Index ready: {idx.ntotal} vectors')
    return idx

def retrieve(query, index, corpus, k=5):
    q_vec = embed_texts([query])
    scores, indices = index.search(q_vec, k)
    results = []
    for i, s in zip(indices[0], scores[0]):
        if 0 <= i < len(corpus):
            p = dict(corpus[i])
            p['_score'] = float(s)
            results.append(p)
    return results

index = build_index(corpus)
print('Embedding functions and FAISS index ready.')
# Out:
# Building index for 9999 pages ...
# Loading sentence-transformers/all-MiniLM-L6-v2 ...
# Model ready.
# Batches:   0%|          | 0/313 [00:00<?, ?it/s]
# Index ready: 9999 vectors
# Embedding functions and FAISS index ready.

# %%
def expand_neighbors(
    query:         str,
    initial_pages: list[dict],
    corpus:        list[dict],
    graph:         nx.DiGraph,
    expand_k:      int = 3,
) -> list[dict]:
    """
    1-hop graph expansion.
    Given the initial retrieved pages, find their neighbors in the graph,
    re-rank by query similarity, and return the top expand_k new pages.
    Returns only the NEW pages (not the initial ones).
    """
    title_to_page   = {p['title']: p for p in corpus}
    initial_titles  = {p['title'] for p in initial_pages}
    neighbor_titles = set()

    for page in initial_pages:
        if not graph.has_node(page['title']):
            continue
        # Out-edges: pages this page links TO
        for nbr in graph.successors(page['title']):
            if nbr in title_to_page and nbr not in initial_titles:
                neighbor_titles.add(nbr)
        # In-edges: pages that link TO this page
        for nbr in graph.predecessors(page['title']):
            if nbr in title_to_page and nbr not in initial_titles:
                neighbor_titles.add(nbr)

    if not neighbor_titles or expand_k <= 0:
        return []

    # Re-rank neighbor candidates by query similarity
    neighbor_pages = [title_to_page[t] for t in neighbor_titles]
    n_embed = embed_texts([p['text'] for p in neighbor_pages])
    q_embed = embed_texts([query])
    scores  = (q_embed @ n_embed.T)[0]             # dot product = cosine sim
    top_idx = scores.argsort()[::-1][:expand_k]    # top expand_k by score
    return [neighbor_pages[i] for i in top_idx]


print('expand_neighbors() defined.')
# Out:
# expand_neighbors() defined.

# %%
# ── Test: see what graph expansion adds for a sample question ─────────────────
q = questions[0]
print(f'Question          : {q["question"]}')
print(f'Gold answer       : {q["answer"]}')
print(f'Supporting pages  : {q["supporting_titles"]}')
print()

initial_pages = retrieve(q['question'], index, corpus, k=5)
neighbors     = expand_neighbors(q['question'], initial_pages, corpus, graph, expand_k=3)

print('FAISS initial retrieval (k=5):')
for p in initial_pages:
    gold = '✓' if p['title'] in q['supporting_titles'] else ' '
    print(f'  {gold} {p["title"][:50]}  (score={p["_score"]:.3f})')
print()
print(f'Graph expansion added {len(neighbors)} new page(s):')
for p in neighbors:
    gold = '✓' if p['title'] in q['supporting_titles'] else ' '
    print(f'  {gold} {p["title"][:50]}')
# Out:
# Question          : The Oberoi family is part of a hotel company that has a head office in what city?
# Gold answer       : Delhi
# Supporting pages  : ['The Oberoi Group', 'Oberoi family']
#
# FAISS initial retrieval (k=5):
#   ✓ Oberoi family  (score=0.651)
#   ✓ The Oberoi Group  (score=0.651)
#     Allard Roen  (score=0.396)
#     InterContinental Hotels Group  (score=0.364)
#     Luxottica  (score=0.358)
#
# Graph expansion added 3 new page(s):
#     Holiday Inn
#     Fossil Group
#     Diageo

# %%
# Visualize the expansion for question 0 (if graph has edges)
if graph.number_of_edges() > 0:
    initial_titles  = [p['title'] for p in initial_pages]
    neighbor_titles = [p['title'] for p in neighbors]
    gold_titles     = set(q['supporting_titles'])

    # Build a small subgraph of relevant nodes
    relevant = set(initial_titles) | set(neighbor_titles) | gold_titles
    subgraph  = graph.subgraph(relevant).copy()
    # Add isolated nodes that aren't connected
    for t in relevant:
        if t not in subgraph:
            subgraph.add_node(t)

    fig, ax = plt.subplots(figsize=(11, 6))
    pos = nx.spring_layout(subgraph, seed=42, k=3)

    def node_color(n):
        if n in gold_titles:      return 'gold'
        if n in initial_titles:   return 'steelblue'
        if n in neighbor_titles:  return 'coral'
        return 'lightgray'

    colors = [node_color(n) for n in subgraph.nodes()]
    nx.draw_networkx(subgraph, pos, node_color=colors, node_size=600,
                     font_size=7, arrows=True, ax=ax)

    gold_p  = mpatches.Patch(color='gold',      label='Gold supporting page')
    init_p  = mpatches.Patch(color='steelblue', label='FAISS initial retrieval')
    exp_p   = mpatches.Patch(color='coral',     label='Graph expansion')
    ax.legend(handles=[gold_p, init_p, exp_p], loc='upper left')
    ax.set_title(f'Graph Expansion — Q: "{q["question"][:55]}..."', fontsize=10)
    ax.axis('off')
    plt.tight_layout()
    plt.savefig(str(DATA_DIR / 'expansion_viz.png'), dpi=100, bbox_inches='tight')
    plt.show()
else:
    print('No graph edges to visualize.')
    print('HyperRAG will fall back to the FAISS initial retrieval.')

# %% [markdown]
# ---
# ## Step 5 — Full HyperRAG Pipeline

# %%
def hyperrag(
    question:  str,
    index:     faiss.IndexFlatIP,
    corpus:    list[dict],
    graph:     nx.DiGraph,
    k:         int = 5,
    expand_k:  int = 3,
) -> tuple[str, list[str]]:
    """
    HyperRAG: dense retrieval + 1-hop graph expansion.

    Returns:
      context        (str)  — plain text of initial + expanded pages
      all_titles     (list) — titles of all pages in context

    Algorithm:
      1. FAISS: retrieve top-k pages
      2. Graph: expand with 1-hop neighbors (re-ranked, top expand_k)
      3. Context = initial pages + expanded pages (plain text)
    """
    initial_pages  = retrieve(question, index, corpus, k=k)
    expanded_pages = expand_neighbors(question, initial_pages, corpus, graph, expand_k=expand_k)
    all_pages      = initial_pages + expanded_pages
    context        = '\n\n'.join(p['text'] for p in all_pages)
    all_titles     = [p['title'] for p in all_pages]
    return context, all_titles


print('hyperrag() defined.')
# Out:
# hyperrag() defined.

# %%
# ── Test HyperRAG on question 0 ───────────────────────────────────────────────
q         = questions[0]
ctx, ttls = hyperrag(q['question'], index, corpus, graph, k=5, expand_k=3)

print(f'Question          : {q["question"]}')
print(f'Gold answer       : {q["answer"]}')
print(f'Supporting pages  : {q["supporting_titles"]}')
print(f'Retrieved titles  : {ttls}')
print(f'Context length    : {len(ctx)} chars')
# Out:
# Question          : The Oberoi family is part of a hotel company that has a head office in what city?
# Gold answer       : Delhi
# Supporting pages  : ['The Oberoi Group', 'Oberoi family']
# Retrieved titles  : ['Oberoi family', 'The Oberoi Group', 'Allard Roen', 'InterContinental Hotels Group', 'Luxottica', 'Holiday Inn', 'Fossil Group', 'Diageo']
# Context length    : 93740 chars

# %% [markdown]
# ---
# ## Step 6 — Evaluate HyperRAG on All 20 Questions

# %%
def compute_em(context, gold_answer):
    return 1.0 if gold_answer.lower() in context.lower() else 0.0

def compute_f1(context, gold_answer):
    pred = context.lower().split()
    gold = gold_answer.lower().split()
    if not pred or not gold:
        return 0.0
    pc = Counter(pred)
    gc = Counter(gold)
    overlap = sum((pc & gc).values())
    p = overlap / len(pred)
    r = overlap / len(gold)
    return 0.0 if p + r == 0 else 2*p*r/(p+r)

def compute_sr(retrieved_titles, gold_titles):
    if not gold_titles:
        return 0.0
    return sum(1 for t in gold_titles if t in set(retrieved_titles)) / len(gold_titles)

print('Metric functions defined.')
# Out:
# Metric functions defined.

# %%
K = 5
EXPAND_K = 3

results_hyper = []
for q in questions:
    ctx, ttls = hyperrag(q['question'], index, corpus, graph, k=K, expand_k=EXPAND_K)
    results_hyper.append({
        'id':               q['id'],
        'question':         q['question'],
        'answer':           q['answer'],
        'em':               compute_em(ctx, q['answer']),
        'f1':               compute_f1(ctx, q['answer']),
        'supporting_recall': compute_sr(ttls, q['supporting_titles']),
    })

mean_em_hyper  = sum(r['em']  for r in results_hyper) / len(results_hyper)
mean_f1_hyper  = sum(r['f1']  for r in results_hyper) / len(results_hyper)
mean_spr_hyper = sum(r['supporting_recall'] for r in results_hyper) / len(results_hyper)

print('HyperRAG Results (k=5, expand_k=3)')
print('=' * 50)
print(f'Mean EM               : {mean_em_hyper:.3f}')
print(f'Mean F1               : {mean_f1_hyper:.3f}')
print(f'Mean Supporting Recall: {mean_spr_hyper:.3f}')
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/9 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/10 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/11 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/7 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/11 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/7 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/9 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/10 [00:00<?, ?it/s]
# Batches:   0%|          | 0/27 [00:00<?, ?it/s]
# Batches:   0%|          | 0/10 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/7 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/10 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/7 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/13 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/11 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/12 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/7 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/7 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/7 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/7 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/11 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# ...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/7 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/7 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/10 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/7 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/19 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/7 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/9 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/7 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/12 [00:00<?, ?it/s]
# Batches:   0%|          | 0/7 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# HyperRAG Results (k=5, expand_k=3)
# ==================================================
# Mean EM               : 0.756
# Mean F1               : 0.000
# Mean Supporting Recall: 0.760

# %% [markdown]
# ---
# ## Step 7 — Final 3-System Comparison
#
# This is the main result of the V2 project: **Simple RAG vs HtmlRAG vs HyperRAG**.

# %%
with open(DATA_DIR / 'results_simple_rag.json') as f:
    simple_data = json.load(f)
with open(DATA_DIR / 'results_htmlrag.json') as f:
    html_data = json.load(f)

print('Loaded results from notebooks 02 and 03.')
print()
print('Summary:')
print(f'{"System":<15} {"EM":>6} {"F1":>6} {"Supp. Recall":>14}')
print('-' * 45)
print(f'{"Simple RAG":<15} {simple_data["mean_em"]:>6.3f} {simple_data["mean_f1"]:>6.3f} {simple_data["mean_sr"]:>14.3f}')
print(f'{"HtmlRAG":<15} {html_data["mean_em"]:>6.3f} {html_data["mean_f1"]:>6.3f} {html_data["mean_sr"]:>14.3f}')
print(f'{"HyperRAG":<15} {mean_em_hyper:>6.3f} {mean_f1_hyper:>6.3f} {mean_spr_hyper:>14.3f}')
# Out:
# Loaded results from notebooks 02 and 03.
#
# Summary:
# System              EM     F1   Supp. Recall
# ---------------------------------------------
# Simple RAG       0.682  0.000          0.663
# HtmlRAG          0.706  0.000          0.663
# HyperRAG         0.756  0.000          0.760

# %%
# ── Final Comparison Bar Chart ────────────────────────────────────────────────
metrics = ['Mean EM', 'Mean F1', 'Mean Supporting\nRecall']
values  = [
    [simple_data['mean_em'],  simple_data['mean_f1'],  simple_data['mean_sr']],
    [html_data['mean_em'],    html_data['mean_f1'],    html_data['mean_sr']],
    [mean_em_hyper,           mean_f1_hyper,           mean_spr_hyper],
]
colors  = ['steelblue', 'teal', 'coral']
labels  = ['Simple RAG', 'HtmlRAG', 'HyperRAG']

x = range(len(metrics))
w = 0.25

fig, ax = plt.subplots(figsize=(10, 5))
for j, (vals, color, label) in enumerate(zip(values, colors, labels)):
    offset = (j - 1) * w
    bars = ax.bar([i + offset for i in x], vals, w, label=label, color=color)
    for bar in bars:
        h = bar.get_height()
        ax.text(bar.get_x() + bar.get_width()/2, h + 0.01, f'{h:.2f}',
                ha='center', va='bottom', fontsize=8.5)

ax.set_xticks(list(x))
ax.set_xticklabels(metrics, fontsize=11)
ax.set_ylabel('Score', fontsize=11)
ax.set_ylim(0, 1.2)
ax.set_title('Simple RAG vs HtmlRAG vs HyperRAG\n(20 HotpotQA bridge questions, k=5)',
             fontsize=12, fontweight='bold')
ax.legend(fontsize=10)
ax.axhline(0, color='black', linewidth=0.5)
plt.tight_layout()
plt.savefig(str(DATA_DIR / 'final_comparison.png'), dpi=120, bbox_inches='tight')
plt.show()
print('Saved: data/final_comparison.png')
# Out:
# Saved: data/final_comparison.png

# %%
# Per-question Supporting Recall: all three systems
ids         = [r['id'] for r in results_hyper]
simple_sr   = [r['supporting_recall'] for r in simple_data['per_question']]
html_sr     = [r['supporting_recall'] for r in html_data['per_question']]
hyper_sr    = [r['supporting_recall'] for r in results_hyper]

fig, ax = plt.subplots(figsize=(13, 4))
w = 0.25
bars1 = ax.bar([i - w for i in ids], simple_sr, w, label='Simple RAG', color='steelblue', alpha=0.85)
bars2 = ax.bar([i      for i in ids], html_sr,   w, label='HtmlRAG',    color='teal',      alpha=0.85)
bars3 = ax.bar([i + w  for i in ids], hyper_sr,  w, label='HyperRAG',   color='coral',     alpha=0.85)
ax.set_xlabel('Question ID')
ax.set_ylabel('Supporting Recall')
ax.set_title('Supporting Recall Per Question — 3 Systems')
ax.set_ylim(0, 1.25)
ax.legend()
plt.tight_layout()
plt.savefig(str(DATA_DIR / 'per_question_sr.png'), dpi=100, bbox_inches='tight')
plt.show()
print('Saved: data/per_question_sr.png')

# %%
# Which questions did HyperRAG improve over Simple RAG?
print('HyperRAG vs Simple RAG — Supporting Recall Per Question')
print(f'{"Q":<4} {"Simple":>8} {"HyperRAG":>10} {"Delta":>8}  {"Question"}')
print('-' * 90)
for sq, hq in zip(simple_data['per_question'], results_hyper):
    delta = hq['supporting_recall'] - sq['supporting_recall']
    sign  = '+' if delta > 0 else ('=' if delta == 0 else '-')
    print(f'{sq["id"]:<4} {sq["supporting_recall"]:>8.2f} {hq["supporting_recall"]:>10.2f} {sign}{abs(delta):>6.2f}  {sq["question"][:50]}')
# Out:
# HyperRAG vs Simple RAG — Supporting Recall Per Question
# Q      Simple   HyperRAG    Delta  Question
# ------------------------------------------------------------------------------------------
# 0        1.00       1.00 =  0.00  The Oberoi family is part of a hotel company that
# 1        1.00       1.00 =  0.00  Musician and satirist Allie Goertz wrote a song ab
# 2        1.00       1.00 =  0.00   What nationality was James Henry Miller's wife?
# 3        1.00       1.00 =  0.00  Cadmium Chloride is slightly soluble in this chemi
# 4        1.00       1.00 =  0.00  Which genus of moth in the world's seventh-largest
# 5        1.00       1.00 =  0.00  Who was once considered the best kick boxer in the
# 6        1.00       1.00 =  0.00  The Dutch-Belgian television series that "House of
# 7        1.00       1.00 =  0.00  What is the length of the track where the 2013 Liq
# 8        1.00       1.00 =  0.00  Fast Cars, Danger, Fire and Knives includes guest
# 9        1.00       1.00 =  0.00  Gunmen from Laredo starred which narrator of "Fron
# 10       1.00       1.00 =  0.00  Where did the form of music played by Die Rhöner S
# 11       1.00       1.00 =  0.00  In which American football game was Malcolm Smith
# 12       0.50       0.50 =  0.00  What U.S Highway gives access to Zilpo Road, and i
# 13       1.00       1.00 =  0.00  The 1988 American comedy film, The Great Outdoors,
# 14       1.00       1.00 =  0.00  What are the names of the current members of  Amer
# 15       1.00       1.00 =  0.00  Human Error" is the season finale of the third sea
# 16       1.00       1.00 =  0.00  Dua Lipa, an English singer, songwriter and model,
# 17       1.00       1.00 =  0.00  American politician Joe Heck ran unsuccessfully ag
# 18       1.00       1.00 =  0.00  Which state does the drug stores, of which the CEO
# 19       1.00       1.00 =  0.00  Which  American politician did Donahue replaced

# %%
with open(DATA_DIR / 'results_hyperrag.json', 'w') as f:
    json.dump({'mean_em': mean_em_hyper, 'mean_f1': mean_f1_hyper, 'mean_sr': mean_spr_hyper,
               'per_question': results_hyper}, f, indent=2)
print('Results saved → data/results_hyperrag.json')
# Out:
# Results saved → data/results_hyperrag.json

# %% [markdown]
# ---
# ## Summary
#
# | System | EM | F1 | Supporting Recall |
# |--------|----|----|-------------------|
# | Simple RAG | see above | see above | see above |
# | HtmlRAG | see above | see above | see above |
# | HyperRAG | see above | see above | see above |
#
# **Key takeaway:**
# - **Supporting Recall** is the most meaningful metric for multi-hop retrieval. It tells you whether the system retrieved *both* pages needed to answer the question.
# - HyperRAG should improve Supporting Recall by following hyperlinks to bridge pages that FAISS would not find on its own.
# - If the corpus is very small (as in this V2), the graph may have few edges, limiting the expansion benefit.
#
# **To see a bigger difference:** increase `N` from 20 to 100 in notebook 01, which will give more pages and a denser graph.
