# %% [markdown]
# # Notebook 3: Simple RAG (Baseline)
#
# **Goal:** Build a minimal but complete RAG pipeline step by step and evaluate it on the HotpotQA questions subset.
#
# **Simple RAG in 4 steps:**
# 1. Embed every page in the corpus as a vector
# 2. Build a FAISS similarity index
# 3. For a query, retrieve the top-k most similar pages
# 4. Return their plain text as context and measure EM / F1
#
# **Prerequisite:** Run `01_data_exploration.ipynb` and `02_data_preparation.ipynb` to create `data/final_corpus.json` and `data/final_questions.json`.

# %%
import json
import sys
from pathlib import Path
from collections import Counter

import faiss
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from sentence_transformers import SentenceTransformer

# ── Paths ─────────────────────────────────────────────────────────────────────
if Path('utils.py').exists():
    BASE_DIR = Path('.')
elif Path('notebooks/utils.py').exists():
    BASE_DIR = Path('v2')
else:
    raise FileNotFoundError('Run from notebooks/ or from HyperRAG-M2/')

DATA_DIR = BASE_DIR / 'data'
CORPUS_PATH    = DATA_DIR / 'final_corpus.json'
QUESTIONS_PATH = DATA_DIR / 'final_questions.json'

# Load data
with open(CORPUS_PATH)    as f: corpus    = json.load(f)
with open(QUESTIONS_PATH) as f: questions = json.load(f)

print(f'Corpus    : {len(corpus)} pages')
print(f'Questions : {len(questions)} questions')
print(f'Keys: corpus={list(corpus[0].keys())}')
# Out:
# W0512 22:44:04.457000 14684 site-packages\torch\distributed\elastic\multiprocessing\redirects.py:29] NOTE: Redirects are currently not supported in Windows or MacOs.
# Corpus    : 24473 pages
# Questions : 7926 questions
# Keys: corpus=['title', 'text', 'html', 'links']

# %%
corpus[0]
# Out:
# {'title': 'The Oberoi Group',
#  'text': 'Indian luxury hotel group The Oberoi Group is a luxury hotel group with its head office in New Delhi , India . Founded in 1934, the company owns and operates 32 luxury hotels and two river cruise ships in 7 countries, primarily under its Oberoi Hotels & Resorts and Trident brands. The group also operates The Oberoi Centre of Learning and Development, which is regarded as one of Asia \'s top institutions for hospitality education. History [ edit ] The foundations of The Oberoi Group date back to 1934 when Rai Bahadur Mohan Singh Oberoi , the founder of the group, bought two properties: the Maidens in Delhi and the Clarkes in Shimla . In the following years Oberoi, assisted by his two sons, Tilak Raj Singh Oberoi and Prithvi Raj Singh Oberoi , continued the expansion of their group with properties both in India and abroad. Ownership [ edit ] Trident, Nariman Point , Mumbai Oberoi Rajvilas, Jaipur The two major holding companies of The Oberoi Group are EIH Ltd and EIH Associated Hotels (formerly East India Hotels). Arjun Singh Oberoi is the current chairman of The Oberoi Group, his cousin, Vikramjit Singh Oberoi is CEO at the holding companies. The Oberoi family is the majority shareholder in EIH Ltd with a 32.11% stake. Conglomerate ITC Limited owns approximately a 14.98% stake in EIH Ltd. To ward off pressures from ITC Ltd. whose ownership stands precariously close to the automatic open offer trigger at 15%, the Oberoi family divested a 14.12% stake in EIH Ltd. to Mukesh Ambani -led Reliance Industries Investment and Holding Pvt Ltd . The stake sale happened on 30 August 2010 for ₹ 10.21 billion (equivalent to ₹ 23 billion or US$270 million in 2023) valuing EIH Ltd. at an enterprise value of ₹ 72 billion (equivalent to ₹ 160 billion or US$1.9 billion in 2023). Recently the stake of Reliance further raised from ITC and it stood at 20% overall for Reliance Industries. Properties [ edit ] The company currently manages 32 hotels under the luxury brand Oberoi Hotels & Resorts , with a further 10 five-star properties under the Trident Hotels brand. The group also operates the Clarkes Hotel in Shimla and the Maidens Hotel, Delhi . However, these two properties are not held under the Trident or under the Oberoi brand. The Clarkes Hotel, after remaining temporarily shut following its lawns caving in because of construction in the eco-sensitive vicinity, reopened on 16 September 2012. See also [ edit ] Taj Hotels The Postcard Hotel References [ edit ] ^ "What are The Oberoi Group\'s three grand pillars of success?" . People Matters . Retrieved 10 December 2017 . ^ " Contact Us ." Oberoi Group. Retrieved on 14 November 2012. "Oberoi Hotels & Resorts 7, Sham Nath Marg, Delhi-110 054, India." ^ "About-us" . Oberoi Hotels. ^ "MS Oberoi: Hotelier Par Excellence" . Financial Express . 4 May 2002. ^ "How Mohan Singh Oberoi Built Hotel Chain Worth Crores From Rs 25 That His Mother Gave Him" . IndiaTimes . 8 July 2021 . Retrieved 20 December 2021 . ^ "About Our Founder" . Oberoi Group . Retrieved 10 December 2015 . ^ "EIH limited about" . ^ "Oberoi Trident" . ^ "ITC non-committal on EIH\'s rights issue" . ^ "Reliance likely to increase stake in Oberoi Group\'s EIH Ltd" . ^ "Oberoi Mohan Singh" . External links [ edit ] Media related to Oberoi Hotels & Resorts at Wikimedia Commons Official website Portals : Companies Hotels',
#  'html': '<div class="mw-content-ltr mw-parser-output" lang="en" dir="ltr"><div class="shortdescription nomobile noexcerpt noprint searchaux" style="display:none">Indian luxury hotel group</div>\n<p class="mw-empty-elt">\n\n</p>\n<style data-mw-deduplicate="TemplateStyles:r1316064257">.mw-parser-output .infobox-subbox{padding:0;border:none;margin:-3px;width:auto;min-width:100%;font-size:100%;clear:none;float:none;background-color:transparent;color:inherit}.mw-parser-output .infobox-3cols-child{margin:-3px}.mw-parser-output .infobox .navbar{font-size:100%}@media screen{html.skin-theme-clientpref-night .mw-parser-output .infobox-full-data:not(.notheme)>div:not(.notheme)[style]{background:#1f1f23!important;color:#f8f9fa}}@media screen and (prefers-color-scheme:dark){html.skin-theme-clientpref-os .mw-parser-output .infobox-full-data:not(.notheme)>div:not(.notheme)[style]{background:#1f1f23!important;color:#f8f9fa}}@media(min-width:640px){body.skin--responsive .mw-parser-output .infobox-table{display:table!important}body.skin--responsive .mw-parser-output .infobox-table>caption{display:table-caption!important}body.skin--responsive .mw-parser-output .infobox-table>tbody{display:table-row-group}body.skin--responsive .mw-parser-output .infobox-table th,body.skin--responsive .mw-parser-output .infobox-table td{padding-left:inherit;padding-right:inherit}}</style><style data-mw-deduplicate="TemplateStyles:r1326365004">.mw-parser-output .ib-company .infobox-label{padding-right:0.5em}.mw-parser-output .ib-company-logo img{background-color:#f8f9fa;color:inherit}.mw-parser-output .ib-company-logo .logo-nobg img{background-color:inherit;color:inherit}.mw-parser-output .ib-company-locality,.mw-parser-output .ib-company-country{display:inline}</style><table class="infobox ib-company vcard"><caption class="infobox-title fn org" style="font-size: 125%;">The Oberoi Group</caption><tbody><tr><td colspan="2" class="infobox-image ib-company-logo logo"><span class="mw-default-size" typeof="mw:File/Frameless"><a href="/wiki/File:The_Oberoi_Group.png" class="mw-file-description"><img src="//upload.wikimedia.org/wikipedia/en/thumb/9/9b/The_Oberoi_Group.png/250px-The_Oberoi_Group.png" decoding="async" width="250" height="67" style="--mw-file-upright: 1" class="mw-file-element mw-file-upright" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/9b/The_Oberoi_Group.png/500px-The_Oberoi_Group.png 2x" data-file-width="528" data-file-height="141" /></a></span></td></tr><tr><th scope="row" class="infobox-label"><div style="display: inline-block; line-height: 1.2em; padding: .1em 0;">Company type</div></th><td class="infobox-data category"><a href="/wiki/Private_company" class="mw-redirect" title="Private company">Private</a></td></tr><tr><th scope="row" class="infobox-label">Industry</th><td class="infobox-data category"><a href="/wiki/Hospitality_industry" title="Hospitality industry">Hospitality industry</a></td></tr><tr><th scope="row" class="infobox-label">Founded</th><td class="infobox-data">1934<span class="noprint">&#59;&#32;92&#160;years ago</span><span style="display:none">&#160;(<span class="bday dtstart published updated">1934</span>)</span></td></tr><tr><th scope="row" class="infobox-label">Founder</th><td class="infobox-data agent"><a href="/wiki/Mohan_Singh_Oberoi" title="Mohan Singh Oberoi">Mohan Singh Oberoi</a></td></tr><tr><th scope="row" class="infobox-label">Headquarters</th><td class="infobox-data label"><a href="/wiki/New_Delhi" title="New Delhi">New Delhi</a>, <a href="/wiki/India" title="India">India</a><span style="display:none" data-plural="0"></span></td></tr><tr><th scope="row" class="infobox-label"><div style="display: inline-block; line-height: 1.2em; padding: .1em 0;">Number of locations</div></th><td class="infobox-data">32&#160;(2017)</td></tr><tr><th scope="row" class="infobox-label"><div style="display: inline-block; line-height: 1.2em; padding: .1em 0;">Area served</div></th><td class="infobox-data">Worldwide</td></tr><tr><th ...
#  'links': ['7 Days Inn',
#   'A&O Hotels and Hostels',
#   'AC Hotels',
#   'ANA Hotels',
#   'APA Group (Japan)',
#   'Accor',
#   'Ace Hotel',
#   'Adagio (hotel)',
#   "Adam's Mark",
#   'Aerowisata',
#   'Aitken Spence Hotel Holdings',
#   'Alamo Plaza Hotel Courts',
#   'Alila Hotels and Resorts',
#   'Allegro Resorts Corporation',
#   'Aloft Hotels',
#   'Aman Resorts',
#   'Amaya Resorts & Spas',
#   'AmeriHost Inn',
#   'AmeriSuites',
#   'AmericInn',
#   'Anantara Hotels, Resorts & Spas',
#   'Apex Hotels',
#   'Apple Leisure Group',
#   'Aqua-Aston Hospitality',
#   'Archipelago International',
#   'Ascend Collection',
#   'Asia',
#   'Atlantis Resorts',
#   'Autograph Collection',
#   'Avani Hotels & Resorts',
#   'Avari Hotels',
#   'Avid Hotels',
#   'Azerai',
#   'Azimut Hotels',
#   'B&B Hotels',
#   'BTG Homeinns',
#   'Bahia Principe',
#   'Banyan Group',
#   'Baymont by Wyndham',
#   'Beaches Resorts',
#   'Beijing Tourism Group',
#   'Belmond Limited',
#   'Best Western',
#   'Budget Host',
#   'Budget Suites of America',
#   'Bulgari Hotels & Resorts',
#   'COMO Hotels and Resorts',
#   'Cachet Hotel Group',
#   'Caesars Entertainment',
#   'Cambria Hotels & Suites',
#   'Canad Inns',
#   'Canalta Hotels',
#   'Candlewood Suites',
#   'Canopy by Hilton',
#   'Capital Bars',
#   'Carlton Hotels & Suites',
#   'Center Parcs Europe',
#   'Center Parcs UK and Ireland',
#   'Ceylon Hotels Corporation',
#   'Choice Hotels',
#   'Cinnamon Hotels & Resorts',
#   'CitizenM',
#   'Citrus Leisure',
#   'Club Med',
#   'Club Quarters',
#   'Coast Hotels',
#   'Cobblestone Hotels',
#   'Comfort Inn and Suites',
#   'Conrad Hotels',
#   'Continental Hotels',
#   'Corinthia Hotels International',
#   'Couples Resorts',
#   'Courtyard by Marriott',
#   'Crest Hotels',
#   'Cross Country Inn',
#   'Crown Resorts',
#   'Crowne Plaza',
#   'Curio (brand)',
#   'Dalata Hotel Group',
#   'Dan Hotels',
#   'Days Inn',
#   'Delhi',
#   'Delta Hotels',
#   'Denizen Hotels',
#   'Design Hotels',
#   'Destination by Hyatt',
#   'Disney Experiences',
#   'Dolce Hotels and Resorts',
#   'Dorsett Hospitality International',
#   'DoubleTree',
#   'Drury Hotels',
#   'Dusit International',
#   'EasyHotel',
#   'Econo Lodge',
#   'Element Hotels',
#   'Embassy Suites by Hilton',
#   'Esso Motor Hotel',
#   'Even Hotels',
#   'ExecuStay',
#   'Exel Inn',
#   'Extended Stay America',
#   'Fairfield by Marriott',
#   'Fairmont Hotels & Resorts',
#   'Fauchon',
#   'Fiesta Inn',
#   'Forte Group',
#   'Four Pillars Hotels',
#   'Four Points by Sheraton',
#   'Four Seasons Hotels and Resorts',
#   'Fred Harvey Company',
#   'Friendship Inn',
#   'Gaylord Hotels',
#   'Ginger Hotels',
#   'Gleneagles Hotel',
#   'Global Hotel Alliance',
#   'Go Hotels',
#   'Graduate Hotels',
#   'Gran Dorado',
#   'Great Southern Hotels',
#   'Grecotel',
#   'Groupe du Louvre',
#   'H World Group Limited',
#   'H World International',
#   'Hampton by Hilton',
#   'Hard Rock Cafe',
#   'Hawthorn Suites',
#   'Hilton Garden Inn',
#   'Hilton Grand Vacations',
#   'Hilton Hotels & Resorts',
#   'Hilton Worldwide',
#   'Hiway House',
#   'Holiday Inn',
#   'Holiday Inn Express',
#   'Home2 Suites by Hilton',
#   'Homewood Suites by Hilton',
#   'Hoshino Resorts',
#   'Hospitality International',
#   'Hospitality industry',
#   'Hotel',
#   'Hotel101',
#   'HotelF1',
#   'Hotel Indigo',
#   'Hotel One',
#   'Hotel RL',
#   'Hotel Shilla',
#   'Hotel Sogo',
#   "Howard Johnson's",
#   'Hyatt',
#   'Hyatt Regency',
#   'IHG Hotels & Resorts',
#   'ITC Hotels',
#   'ITC Limited',
#   'Iberostar Group',
#   'Ibis (hotel)',
#   'Ibis Budget',
#   'Ibis Styles',
#   'Imperial 400',
#   'InTown Suites',
#   'India',
#   'Indian Hotels Company Limited',
#   'Indian rupee',
#   'InterContinental',
#   'Isrotel',
#   'JAL Hotels',
#   'JW Marriott Hotels',
#   'Jack Tar Hotels',
#   'Jaipur',
#   'Jameson Inn',
#   'Jetwing Hotels',
#   'Jetwing Symphony',
#   "Jimmy Buffett's Margaritaville",
#   'Jin Jiang Hotels',
#   'Jinjiang Inn',
#   'Jinjiang International',
#   'Jo&Joe',
#   'Joie de Vivre Hospitality',
#   'Jumeirah (hotel chain)',
#   'Jurys Inn',
#   'Kempinski',
#   'Kerry Properties',
#   'Kimpton Hotels & Restaurants',
#   'Knights Inn',
#   'Kuriftu Resorts & Spa',
#   'La Quinta Inns & Suites',
#   'Langham Hospitality Group',
#   'Las Vegas Sands',
#   'Le Méridien',
#   'Lemon Tree Hotels',
#   'List of Marriott hotels',
#   'List of chained-brand hotels',
#   'List of defunct hotel chains',
#   'Loews Hotels',
#   'Lotte Hotels & Resorts',
#   'Luxury hotel',
#   'MGM Resorts International',
#   'Magnuson Hotels',
#   'Maidens Hotel, Delhi',
#   'MainStay Suites',
#   'Maisons Cheval Blanc',
#   'Mama Shelter',
#   'Mamaison Hotels & Residences',
#   'Mandarin Oriental Hotel Group',
#   'Marco Polo Hotels',
#   'Marriott Hotels & Resorts',
#   'Marriott International',
#   'Marriott Vacation Club',
#   'Masters Inn',
#   'Meliá Hotels International',
#   'Mercure (hotel)',
#   'Metropolo Hotel',
#   'Microtel Inn and Suites',
#   'Millennium & Copthorne Hotels',
#   'Minor Hotels',
#   'Miyako Hotels & Resorts',
#   'Mohan Singh Oberoi',
#   'Montage Hotels & Resorts',
#   'Motel 168',
#   'Motel 6',
#   'Motel One',
#   'Mukesh Ambani',
#   'Mumbai',
#   'Mövenpick Hotels & Resorts',
#   'NH Hotel Group',
#   'New Delhi',
#   'Nickelodeon Resorts by Marriott',
#   'Nikki Beach',
#   'Nikko Hotels',
#   'Northland Properties',
#   'Novotel',
#   'Novotel Suites',
#   'Oaks Hotels, Resorts & Suites',
#   'Oetker Hotels',
#   'Okura Hotels',
#   'Okura Nikko Hotel Management',
#   'Omni Hotels & Resorts',
#   'Orient Express',
#   'Outrigger Hotels & Resorts',
#   'Oyo Rooms',
#   'PPHE Hotel Group',
#   'Pan Pacific Hotels and Resorts',
#   'Paradores',
#   'Park Plaza Hotels & Resorts',
#   'Parliament House Motor Inn',
#   'Patio Hotels',
#   'Pearl-Continental Hotels & Resorts',
#   'Penta Hotels',
#   'Peppermint Hotels',
#   'Pestana Group',
#   'Pousadas de Portugal',
#   'Preferred Hotels & Resorts',
#   'Premier Inn',
#   'Prime Plaza Hotels and Resorts',
#   'Prince Hotels',
#   'Prithvi Raj Singh Oberoi',
#   'Private company',
#   'Promus Hotel Corporation',
#   'Protea Hotels by Marriott',
#   'Pullman Hotels and Resorts',
#   'QT Hotels & Resorts',
#   'Quality Inn',
#   'RIU Hotels',
#   'Radisson Blu',
#   'Radisson Hotel Group',
#   'Radisson Hotels',
#   'Radisson Red',
#   'Raffles Hotels & Resorts',
#   'Rai Bahadur',
#   'Ramada',
#   'Real Hotel Company',
#   'Red Carpet Inn',
#   'Red Lion Hotels',
#   'Red Lion Hotels Corporation',
#   'Red Planet Hotels',
#   'Red Roof Inn',
#   'Regent Hotels & Resorts',
#   'Relais & Châteaux',
#   'Reliance Industries',
#   'Renaissance Hotels',
#   'Residence Inn by Marriott',
#   'Resort',
#   'Rezidor Hotel Group',
#   'River cruise',
#   'Rixos Hotels',
#   'Rocco Forte Hotels',
#   'Rodeway Inn',
#   'Rosewood Hotels & Resorts',
#   'Rotana Hotels',
#   'Royal Inns of America',
#   'Royal Orchid Hotels',
#   'Rydges Hotels & Resorts',
#   'SBE Entertainment Group',
#   'Sahid Group',
#   'Sandals Resorts',
#   'Sandman Hotels',
#   'Santika Indonesia Hotels & Resorts',
#   'Scandic Hotels',
#   'Scottish Inns',
#   'Seda Hotels',
#   'Serena Hotels',
#   'Shangri-La Hotels and Resorts',
#   'Sheraton Hotels and Resorts',
#   'Shimla',
#   "Shoney's",
#   'Sleep Inn',
#   'Sofitel',
#   'Sonder (company)',
#   'Sonesta International Hotels',
#   'Soneva',
#   'Spark by Hilton',
#   'SpringHill Suites',
#   'St. Regis Hotels & Resorts',
#   'Standard Hotels',
#   'Star Entertainment Group',
#   'Starhotels',
#   'Starwood Hotels and Resorts',
#   'Statler Hotels',
#   'Staybridge Suites',
#   'Strawberry (hotel company)',
#   'Summerfield Suites',
#   'Summit Hotels and Resorts',
#   'Sun International',
#   'Super 8 (hotel)',
#   'Susse Chalet',
#   'Swallow Hotels',
#   'Swiss-Belhotel International',
#   'Swissôtel',
#   'TRYP by Wyndham',
#   'Tage Inn',
#   'Taj Hotels',
#   'The Ascott Limited',
#   'The Dedica Anthology Hotels',
#   'The Doyle Collection',
#   'The Hotel Collection',
#   'The Hoxton',
#   'The Leading Hotels of the World',
#   'The Leela',
#   'The Luxury Collection',
#   'The Peninsula Hotels',
#   'The Postcard Hotel',
#   'The Ritz-Carlton Hotel Company',
#   'The Sukhothai Hotels & Resorts',
#   'The Trump Organization',
#   'The Wharf (Holdings)',
#   'Thistle Hotels',
#   'Thon Hotels',
#   'TownePlace Suites',
#   'Toyoko Inn',
#   'Traders Hotel',
#   'Travelodge',
#   'Travelodge (British company)',
#   'Tribute Portfolio',
#   'Trident Hotel, Nariman Point',
#   'Trident Hotels',
#   'Tru by Hilton',
#   'Tune Hotels',
#   'United Hotels Company of America',
#   'Vantage Hospitality',
#   'Vienna Hotels',
#   'Virgin Hotels',
#   'Vivanta',
#   'Voco',
#   'W Hotels',
#   'Waldorf Astoria Hotels & Resorts',
#   'Warwick Hotels and Resorts',
#   'Westin Hotels & Resorts',
#   'Wilson World Hotels',
#   'Wingate by Wyndham',
#   'WoodSpring Suites',
#   'Wyndham Hotels & Resorts',
#   'Wynn Resorts',
#   'Yotel',
#   'Zleep Hotels']}

# %% [markdown]
# ---
# ## Step 1 — Embed Texts
#
# Convert each Wikipedia page into a **dense vector** using `sentence-transformers/all-MiniLM-L6-v2`.
# Every vector is then **L2-normalised** so that the inner product equals the cosine similarity.
#
# > Cosine similarity = 1.0 means identical direction, 0.0 means completely unrelated.

# %%
MODEL_NAME = 'sentence-transformers/all-MiniLM-L6-v2'
_model = None  

def get_model() -> SentenceTransformer:
    """Load (or return cached) SentenceTransformer model."""
    global _model
    if _model is None:
        print(f'Loading model: {MODEL_NAME} ...')
        _model = SentenceTransformer(MODEL_NAME)
        print('Model loaded.')
    return _model


def embed_texts(texts: list[str]) -> np.ndarray:
    """
    Embed a list of strings into L2-normalised float32 vectors.
    Output shape: (len(texts), 384).
    """
    model  = get_model()
    vecs   = model.encode(texts, show_progress_bar=len(texts) > 20, convert_to_numpy=True)
    vecs   = vecs.astype('float32')
    faiss.normalize_L2(vecs)   # in-place L2 normalisation
    return vecs


print('embed_texts() defined.')
# Out:
# embed_texts() defined.

# %%
# ── Test embed_texts ──────────────────────────────────────────────────────────
test_texts = [
    'Paris is the capital of France.',
    'Berlin is the capital of Germany.',
    'Mount Everest is the tallest mountain on Earth.',
]
vecs = embed_texts(test_texts)
print(f'Output shape  : {vecs.shape}    (3 texts, 384-dim vectors)')
print(f'Vector dtype  : {vecs.dtype}')
print(f'L2 norms      : {np.linalg.norm(vecs, axis=1)}  (should all be ~1.0)')
print()
# Compute cosine similarities (= dot products after L2 norm)
sim_matrix = vecs @ vecs.T
print('Cosine similarity matrix (Paris, Berlin, Everest):')
print(np.round(sim_matrix, 3))
print('  → Paris↔Berlin should be more similar than Paris↔Everest')
# Out:
# Output shape  : (3, 384)    (3 texts, 384-dim vectors)
# Vector dtype  : float32
# L2 norms      : [1. 1. 1.]  (should all be ~1.0)
#
# Cosine similarity matrix (Paris, Berlin, Everest):
# [[1.    0.348 0.077]
#  [0.348 1.    0.094]
#  [0.077 0.094 1.   ]]
#   → Paris↔Berlin should be more similar than Paris↔Everest

# %% [markdown]
# ---
# ## Step 2 — Build FAISS Index
#
# **FAISS** (Facebook AI Similarity Search) stores all corpus vectors and lets us find the most similar ones to a query vector in milliseconds.
#
# We use `IndexFlatIP` (inner product = cosine similarity after L2 normalisation).

# %%
def build_index(corpus: list[dict]) -> faiss.IndexFlatIP:
    """
    Embed every page in corpus and store vectors in a FAISS index.
    The order of pages in the index matches the order in corpus.
    Returns: faiss.IndexFlatIP ready for .search().
    """
    print(f'Embedding {len(corpus)} pages ...')
    texts      = [p['text'] for p in corpus]
    embeddings = embed_texts(texts)
    dim        = embeddings.shape[1]
    index      = faiss.IndexFlatIP(dim)
    index.add(embeddings)
    print(f'Index built: {index.ntotal} vectors, dim={dim}')
    return index


print('build_index() defined.')
# Out:
# build_index() defined.

# %%
# ── Test: build index from 3 dummy pages ──────────────────────────────────────
dummy_corpus = [
    {'title': 'Paris',   'text': 'Paris is the capital of France.', 'html': '', 'links': []},
    {'title': 'Berlin',  'text': 'Berlin is the capital of Germany.', 'html': '', 'links': []},
    {'title': 'Everest', 'text': 'Mount Everest is the tallest mountain.', 'html': '', 'links': []},
]
dummy_index = build_index(dummy_corpus)
print(f'Vectors in index : {dummy_index.ntotal}')
# Out:
# Embedding 3 pages ...
# Index built: 3 vectors, dim=384
# Vectors in index : 3

# %%
from pathlib import Path
import faiss, json

data_dir = Path("data")
data_dir.mkdir(exist_ok=True)

faiss.write_index(dummy_index, str(data_dir / "dummy_faiss_index.bin"))

page_ids = [doc["title"] for doc in dummy_corpus]
(data_dir / "faiss_ids.json").write_text(json.dumps(page_ids))

print(f"Index saved: {dummy_index.ntotal} vectors → {data_dir}/dummy_faiss_index.bin")
# Out:
# Index saved: 3 vectors → data/dummy_faiss_index.bin

# %%
index    = faiss.read_index(str(data_dir / "dummy_faiss_index.bin"))
page_ids = json.loads((data_dir / "faiss_ids.json").read_text())
print(f"Loaded: {index.ntotal} vectors, {len(page_ids)} titles")
# Out:
# Loaded: 3 vectors, 3 titles

# %%
from pathlib import Path
import faiss, json

data_dir = Path("data")
index_path = data_dir / "faiss_index.bin"
ids_path   = data_dir / "faiss_ids.json"

if index_path.exists() and ids_path.exists():
    index    = faiss.read_index(str(index_path))
    page_ids = json.loads(ids_path.read_text())
    print(f"Loaded cached index: {index.ntotal} vectors")
else:
    index    = build_index(corpus)
    page_ids = [doc["title"] for doc in corpus]
    data_dir.mkdir(exist_ok=True)
    faiss.write_index(index, str(index_path))
    ids_path.write_text(json.dumps(page_ids))
    print(f"Built and saved index: {index.ntotal} vectors")
# Out:
# Embedding 24473 pages ...
# Batches:   0%|          | 0/765 [00:00<?, ?it/s]
# Index built: 24473 vectors, dim=384
# Built and saved index: 24473 vectors

# %% [markdown]
# ---
# ## Step 3 — Retrieval Function
#
# For a query string we:
# 1. Embed the query into a vector
# 2. Ask FAISS for the k nearest vectors (highest cosine similarity)
# 3. Map indices back to corpus pages

# %%
def retrieve(
    query:  str,
    index:  faiss.IndexFlatIP,
    corpus: list[dict],
    k:      int = 5,
) -> list[dict]:
    """
    Retrieve top-k most similar pages to query.
    Each returned dict has all original keys PLUS '_score' (cosine similarity).
    """
    q_vec = embed_texts([query])
    scores, indices = index.search(q_vec, k)
    results = []
    for idx, score in zip(indices[0], scores[0]):
        if 0 <= idx < len(corpus):
            page = dict(corpus[idx])           # shallow copy
            page['_score'] = float(score)
            results.append(page)
    return results


print('retrieve() defined.')
# Out:
# retrieve() defined.

# %%
# ── Test: retrieve top-3 pages for a sample question ─────────────────────────
test_q = questions[0]
print(f'Question : {test_q["question"]}')
print(f'Answer   : {test_q["answer"]}')
print(f'Needs    : {test_q["supporting_titles"]}')
print()

results = retrieve(test_q['question'], index, corpus, k=3)
print('Top-3 retrieved pages:')
print(f'{"Rank":<5} {"Score":>6}  {"Title"}')
print('-' * 55)
for rank, page in enumerate(results, 1):
    is_gold = '✓' if page['title'] in test_q['supporting_titles'] else ' '
    print(f'{rank:<5} {page["_score"]:>6.3f}  {is_gold} {page["title"]}')
# Out:
# Question : The Oberoi family is part of a hotel company that has a head office in what city?
# Answer   : Delhi
# Needs    : ['The Oberoi Group', 'Oberoi family']
#
# Top-3 retrieved pages:
# Rank   Score  Title
# -------------------------------------------------------
# 1      0.651  ✓ Oberoi family
# 2      0.651  ✓ The Oberoi Group
# 3      0.417    Hilton Worldwide

# %%
# Visualize similarity scores for the first question
results_5 = retrieve(test_q['question'], index, corpus, k=5)
titles = [p['title'][:30] for p in results_5]
scores = [p['_score'] for p in results_5]
gold   = set(test_q['supporting_titles'])
colors = ['gold' if t in gold else 'steelblue' for t in [p['title'] for p in results_5]]

plt.figure(figsize=(10, 5))
plt.barh(titles[::-1], scores[::-1], color=colors[::-1])
plt.xlabel('Cosine Similarity')
plt.title(f'Retrieval Scores — "{test_q["question"][:5]}..."')
gold_patch  = mpatches.Patch(color='gold',      label='Gold supporting page')
blue_patch  = mpatches.Patch(color='steelblue', label='Other page')
plt.legend(handles=[gold_patch, blue_patch])
plt.tight_layout()
plt.savefig(str(DATA_DIR / 'simple_rag_scores.png'), dpi=100, bbox_inches='tight')
plt.show()

# %% [markdown]
# ---
# ## Step 4 — Evaluation Metrics: EM and F1
#
# We measure retrieval quality — not generation quality:
# - **EM (Exact Match):** 1 if the gold answer string appears in the retrieved context
# - **F1:** token-level word overlap between context and gold answer
# - **Supporting Recall:** fraction of gold pages that were retrieved (best metric for multi-hop)

# %%
def compute_em(context: str, gold_answer: str) -> float:
    """
    Exact Match: 1.0 if gold answer appears case-insensitively in context.
    Simple substring check — fast and interpretable.
    """
    return 1.0 if gold_answer.lower() in context.lower() else 0.0


def compute_f1(context: str, gold_answer: str) -> float:
    """
    Token F1: word-level overlap between context and gold answer.
    Based on multiset intersection of lowercased whitespace tokens.
    """
    pred_tokens = context.lower().split()
    gold_tokens = gold_answer.lower().split()
    if not pred_tokens or not gold_tokens:
        return 0.0
    pred_c  = Counter(pred_tokens)
    gold_c  = Counter(gold_tokens)
    overlap = sum((pred_c & gold_c).values())
    precision = overlap / len(pred_tokens)
    recall    = overlap / len(gold_tokens)
    if precision + recall == 0:
        return 0.0
    return 2 * precision * recall / (precision + recall)


def compute_supporting_recall(
    retrieved_titles: list[str],
    gold_titles:      list[str],
) -> float:
    """
    What fraction of the gold supporting pages were retrieved?
    This is the KEY metric for multi-hop retrieval.
    Example: gold=[A,B], retrieved=[A,C,D] → recall = 0.5
    """
    if not gold_titles:
        return 0.0
    hits = sum(1 for t in gold_titles if t in set(retrieved_titles))
    return hits / len(gold_titles)


print('compute_em(), compute_f1(), compute_supporting_recall() defined.')
# Out:
# compute_em(), compute_f1(), compute_supporting_recall() defined.

# %%
# ── Test each metric on a hand-crafted example ───────────────────────────────
context      = 'The capital of France is Paris and it is a famous city.'
gold_answer  = 'Paris'

em = compute_em(context, gold_answer)
f1 = compute_f1(context, gold_answer)
print(f'context : "{context}"')
print(f'gold    : "{gold_answer}"')
print(f'EM      : {em}   (1.0 because "Paris" is in the context)')
print(f'F1      : {f1:.3f}')
print()

context2     = 'Berlin is a big city in Germany.'
gold_answer2 = 'Paris'
em2 = compute_em(context2, gold_answer2)
f1_2 = compute_f1(context2, gold_answer2)
print(f'context : "{context2}"')
print(f'gold    : "{gold_answer2}"')
print(f'EM      : {em2}   (0.0 because "Paris" is NOT in the context)')
print(f'F1      : {f1_2:.3f}')
print()

# Supporting recall
recall_full  = compute_supporting_recall(['A', 'B', 'C'], ['A', 'B'])
recall_half  = compute_supporting_recall(['A', 'C', 'D'], ['A', 'B'])
recall_zero  = compute_supporting_recall(['C', 'D', 'E'], ['A', 'B'])
print(f'Supporting recall (got both gold pages)   : {recall_full}')
print(f'Supporting recall (got one of two)        : {recall_half}')
print(f'Supporting recall (got neither gold page) : {recall_zero}')
# Out:
# context : "The capital of France is Paris and it is a famous city."
# gold    : "Paris"
# EM      : 1.0   (1.0 because "Paris" is in the context)
# F1      : 0.154
#
# context : "Berlin is a big city in Germany."
# gold    : "Paris"
# EM      : 0.0   (0.0 because "Paris" is NOT in the context)
# F1      : 0.000
#
# Supporting recall (got both gold pages)   : 1.0
# Supporting recall (got one of two)        : 0.5
# Supporting recall (got neither gold page) : 0.0

# %% [markdown]
# ---
# ## Step 5 — Full Simple RAG Pipeline
#
# Put everything together: retrieve top-k pages and concatenate their plain text as context.

# %%
def simple_rag(
    question: str,
    index:    faiss.IndexFlatIP,
    corpus:   list[dict],
    k:        int = 5,
) -> str:
    """
    Simple RAG: retrieve top-k pages, return plain text concatenated.
    This is the baseline (B1) all other systems are compared against.
    """
    pages   = retrieve(question, index, corpus, k=k)
    context = '\n\n'.join(p['text'] for p in pages)
    return context


print('simple_rag() defined.')
# Out:
# simple_rag() defined.

# %%
# ── Test the full pipeline on question 0 ─────────────────────────────────────
q    = questions[0]
ctx  = simple_rag(q['question'], index, corpus, k=5)
em   = compute_em(ctx, q['answer'])
f1   = compute_f1(ctx, q['answer'])

print(f'Question         : {q["question"]}')
print(f'Gold answer      : {q["answer"]}')
print(f'Supporting pages : {q["supporting_titles"]}')
print(f'Context length   : {len(ctx)} chars')
print(f'EM               : {em}')
print(f'F1               : {f1:.3f}')
print()
print('Context preview (first 400 chars):')
print(ctx[:400])
# Out:
# Question         : The Oberoi family is part of a hotel company that has a head office in what city?
# Gold answer      : Delhi
# Supporting pages : ['The Oberoi Group', 'Oberoi family']
# Context length   : 55899 chars
# EM               : 1.0
# F1               : 0.000
#
# Context preview (first 400 chars):
# Indian luxury hotel group The Oberoi Group is a luxury hotel group with its head office in New Delhi , India . Founded in 1934, the company owns and operates 32 luxury hotels and two river cruise ships in 7 countries, primarily under its Oberoi Hotels & Resorts and Trident brands. The group also operates The Oberoi Centre of Learning and Development, which is regarded as one of Asia 's top institu

# %% [markdown]
# ---
# ## Step 6 — Evaluate on All Questions

# %%
K = 5   # number of pages to retrieve

results_simple = []
for q in questions:
    pages   = retrieve(q['question'], index, corpus, k=K)
    context = '\n\n'.join(p['text'] for p in pages)
    ret_titles = [p['title'] for p in pages]

    em       = compute_em(context, q['answer'])
    f1       = compute_f1(context, q['answer'])
    sp_recall = compute_supporting_recall(ret_titles, q['supporting_titles'])

    results_simple.append({
        'id':               q['id'],
        'question':         q['question'],
        'answer':           q['answer'],
        'em':               em,
        'f1':               f1,
        'supporting_recall': sp_recall,
        'retrieved_titles': ret_titles,
    })

mean_em  = sum(r['em']  for r in results_simple) / len(results_simple)
mean_f1  = sum(r['f1']  for r in results_simple) / len(results_simple)
mean_spr = sum(r['supporting_recall'] for r in results_simple) / len(results_simple)

print('Simple RAG Results (k=5)')
print('=' * 50)
print(f'Mean EM               : {mean_em:.3f}')
print(f'Mean F1               : {mean_f1:.3f}')
print(f'Mean Supporting Recall: {mean_spr:.3f}')
# Out:
# Simple RAG Results (k=5)
# ==================================================
# Mean EM               : 0.474
# Mean F1               : 0.000
# Mean Supporting Recall: 0.535

# %%
# Per-question results table
print(f'{"#":<4} {"EM":>4} {"F1":>6} {"SR":>6}  Answer')
print('-' * 60)
for r in results_simple:
    print(f'{r["id"]:<4} {r["em"]:>4.0f} {r["f1"]:>6.3f} {r["supporting_recall"]:>6.3f}  {r["answer"][:30]}')
# Out:
# #      EM     F1     SR  Answer
# ------------------------------------------------------------
# 0       1  0.000  1.000  Delhi
# 1       1  0.000  1.000  President Richard Nixon
# 2       1  0.000  0.000  American
# 3       1  0.000  0.500  alcohol
# 4       1  0.007  0.500  Crambidae
# 5       1  0.000  0.500  Badr Hari
# 6       1  0.000  1.000  2006
# 7       0  0.001  1.000  6.213 km long
# 8       0  0.000  0.000  Jaime Meline
# 9       0  0.000  0.500  Walter Darwin Coy
# 10      1  0.000  0.500  United States
# 11      1  0.000  0.500  Super Bowl XLVIII
# 12      1  0.000  0.000  US 60
# 13      1  0.000  0.500  2006
# 14      0  0.001  1.000  Hetfield and Ulrich, longtime
# 15      1  0.000  0.000  Fox
# 16      1  0.000  1.000  2017
# 39792    0  0.000  0.000  McComb, Mississippi
# 39801    0  0.000  0.500  December 1954
# 39816    0  0.000  0.500  1960
# 39827    0  0.000  0.500  May 17, 1982
# 39848    0  0.000  0.500  Bruce Joel Rubin
# 39868    0  0.000  0.000  England, Denmark, and Norway
# 39870    0  0.000  0.500  Ben Affleck
# 39880    1  0.000  0.000  Denver Nuggets
# 39881    0  0.000  0.000  comic books
# 39884    0  0.001  0.500  House of Commons
# 39912    0  0.000  0.500  Metropolitan
# 39917    0  0.000  0.500  1,152,425
# 39927    0  0.000  0.500  27 November 1943
# 39938    0  0.000  0.500  MetLife Stadium
# 39948    0  0.000  0.000  19th
# 39949    0  0.001  0.500  the New York Yankees
# 39993    0  0.000  0.500  Laura Mackenzie Phillips
# 39994    0  0.000  0.000  Glacier County
# 40007    0  0.000  0.500  Mahwah
# 40009    0  0.000  0.500  Michael Caine
# 40012    0  0.000  0.500  Houston County
# 40018    0  0.000  0.500  1984
# 40020    0  0.000  0.500  Luke
# 40046    0  0.000  0.500  Bill Chambers
# 40052    0  0.001  0.500  Jackson County
# 40081    0  0.000  0.500  Russian
# 40116    1  0.000  0.500  1958
# 40126    1  0.000  0.500  Dorothy Dandridge
# 40128    1  0.000  0.500  56
# 40153    0  0.000  0.500  Triangle Below Canal Street
# 40178    0  0.000  0.500  Wy'east
# 40206    0  0.000  0.500  1890
# 40209    0  0.000  0.500  124,775
# 40233    0  0.000  0.500  professional footballer
# 40261    1  0.000  0.000  Stephen King
# 40284    1  0.001  0.000  four times
# 40289    1  0.000  0.500  1943
# 40312    1  0.000  0.500  Swami Vivekananda

# %%
em_vals  = [r['em']  for r in results_simple[:5000]]
f1_vals  = [r['f1']  for r in results_simple[:5000]]
sr_vals  = [r['supporting_recall'] for r in results_simple[:5000]]
ids      = [r['id']  for r in results_simple[:5000]]

fig, axes = plt.subplots(1, 3, figsize=(15, 4))
fig.suptitle('Simple RAG — Per-Question Scores', fontsize=13, fontweight='bold')

for ax, vals, label, color, mean_val in [
    (axes[0], em_vals,  'EM',               'steelblue', mean_em),
    (axes[1], f1_vals,  'F1',               'teal',      mean_f1),
    (axes[2], sr_vals,  'Supporting Recall', 'coral',    mean_spr),
]:
    ax.bar(ids, vals, color=color)
    ax.axhline(mean_val, color='red', linestyle='--', label=f'mean={mean_val:.2f}')
    ax.set_xlabel('Question ID')
    ax.set_ylabel(label)
    ax.set_title(label)
    ax.set_ylim(0, 1.05)
    ax.legend()

plt.tight_layout()
plt.savefig(str(DATA_DIR / 'simple_rag_results.png'), dpi=100, bbox_inches='tight')
plt.show()
print('Saved: data/simple_rag_results.png')
# Out:
# Saved: data/simple_rag_results.png

# %%
# Save results for comparison in notebook 4
import json
with open(DATA_DIR / 'results_simple_rag.json', 'w') as f:
    json.dump({'mean_em': mean_em, 'mean_f1': mean_f1, 'mean_sr': mean_spr,
               'per_question': results_simple}, f, indent=2)
print('Results saved → data/results_simple_rag.json')
print()
print('Open notebook 04_htmlrag.ipynb next.')
# Out:
# Results saved → data/results_simple_rag.json
#
# Open notebook 03_htmlrag.ipynb next.
